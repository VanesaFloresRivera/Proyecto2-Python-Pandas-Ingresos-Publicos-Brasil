# %%
# Tratamiento de datos
import pandas as pd
# Ignorar warnings
import warnings
warnings.filterwarnings("ignore")
# Configuración
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames
#importar la biblioteca de numpy:
import numpy as np
from src import soporte_EDA as se
pd.options.display.float_format = '{:.2f}'.format # para redondearlo todo a 2 decimales

# %%
df_datos_2013 = pd.read_csv("datos/datos-2013.csv" , sep=';', encoding='latin-1')
df_datos_2014 = pd.read_csv("datos/datos-2014.csv" , sep=';', encoding='latin-1')
df_datos_2015 = pd.read_csv("datos/datos-2015.csv" , sep=';', encoding='latin-1')
df_datos_2016 = pd.read_csv("datos/datos-2016.csv" , sep=';', encoding='latin-1')
df_datos_2017 = pd.read_csv("datos/datos-2017.csv" , sep=';', encoding='latin-1')
df_datos_2018 = pd.read_csv("datos/datos-2018.csv" , sep=';', encoding='latin-1')
df_datos_2019 = pd.read_csv("datos/datos-2019.csv" , sep=';', encoding='latin-1')
df_datos_2020 = pd.read_csv("datos/datos-2020.csv" , sep=';', encoding='latin-1')
df_datos_2021 = pd.read_csv("datos/datos-2021.csv" , sep=';', encoding='latin-1')
df_diccionario_datos = pd.read_csv("datos/diccionario_datos.csv" , sep=';', encoding='latin-1')

# %%
import os

# %%
os.listdir('datos/')
# Out:
# ['datos-2013.csv',
#  'datos-2014.csv',
#  'datos-2015.csv',
#  'datos-2016.csv',
#  'datos-2017.csv',
#  'datos-2018.csv',
#  'datos-2019.csv',
#  'datos-2020.csv',
#  'datos-2021.csv',
#  'diccionario_datos.csv']

# %%
lista_archivos = os.listdir('datos/')[:-1]
lista_archivos
# Out:
# ['datos-2013.csv',
#  'datos-2014.csv',
#  'datos-2015.csv',
#  'datos-2016.csv',
#  'datos-2017.csv',
#  'datos-2018.csv',
#  'datos-2019.csv',
#  'datos-2020.csv',
#  'datos-2021.csv']

# %%
def carga_ficheros(lista_ficheros):
    diccionario_datos ={}
    for fichero in lista_ficheros:
        clave = 'df_datos_'+fichero[6:10]
        pd.read_csv(f"datos/{fichero}", sep=';', encoding='latin-1')
        diccionario_datos[clave] = pd.read_csv(f"datos/{fichero}", sep=';', encoding='latin-1')
    return diccionario_datos

# %%
diccionario = carga_ficheros(lista_archivos)

# %%
diccionario['df_datos_2013']
# Out:
#       CÓDIGO ÓRGÃO SUPERIOR       NOME ÓRGÃO SUPERIOR  CÓDIGO ÓRGÃO  \
# 0                     63000  Advocacia-Geral da União         63000
# 1                     63000  Advocacia-Geral da União         63000
# 2                     63000  Advocacia-Geral da União         63000
# 3                     63000  Advocacia-Geral da União         63000
# 4                     63000  Advocacia-Geral da União         63000
# ...                     ...                       ...           ...
# 4493                  20000  Presidência da República         20101
# 4494                  20000  Presidência da República         64000
# 4495                  20000  Presidência da República         20101
# 4496                  20000  Presidência da República         20116
# 4497                  20000  Presidência da República         24208
#
#                                              NOME ÓRGÃO  \
# 0     Advocacia-Geral da União - Unidades com víncul...
# ...

# %%
diccionario_datos['df_datos_2013']
# Out:
#       CÓDIGO ÓRGÃO SUPERIOR       NOME ÓRGÃO SUPERIOR  CÓDIGO ÓRGÃO  \
# 0                     63000  Advocacia-Geral da União         63000
# 1                     63000  Advocacia-Geral da União         63000
# 2                     63000  Advocacia-Geral da União         63000
# 3                     63000  Advocacia-Geral da União         63000
# 4                     63000  Advocacia-Geral da União         63000
# ...                     ...                       ...           ...
# 4493                  20000  Presidência da República         20101
# 4494                  20000  Presidência da República         64000
# 4495                  20000  Presidência da República         20101
# 4496                  20000  Presidência da República         20116
# 4497                  20000  Presidência da República         24208
#
#                                              NOME ÓRGÃO  \
# 0     Advocacia-Geral da União - Unidades com víncul...
# ...

# %%
diccionario_verduras['brocoli'] = 1
diccionario_verduras['tomates'] =4
diccionario_verduras
# Out:
# {'brocoli': 1, 'tomates': 4}

# %% [markdown]
# ## Comprobación de los nombres de las columnas

# %%
lista_columnas = []
lista_columnas.append(list(df_datos_2013.columns))
lista_columnas.append(list(df_datos_2014.columns))
lista_columnas.append(list(df_datos_2015.columns))
lista_columnas.append(list(df_datos_2016.columns))
lista_columnas.append(list(df_datos_2017.columns))
lista_columnas.append(list(df_datos_2018.columns))
lista_columnas.append(list(df_datos_2019.columns))
lista_columnas.append(list(df_datos_2020.columns))
lista_columnas.append(list(df_datos_2021.columns))
lista_columnas[0]==lista_columnas[1] == lista_columnas[2] == lista_columnas[3] == lista_columnas[4] == lista_columnas[5]== lista_columnas[6]== lista_columnas[7]== lista_columnas[8]
# Out:
# True

# %% [markdown]
# ## Limpieza diccionario datos

# %%
df_diccionario_datos
# Out:
#                     COLUNA  Unnamed: 1  \
# 0                      NaN         NaN
# 1    Código Órgão Superior         NaN
# 2                      NaN         NaN
# 3                      NaN         NaN
# 4      Nome Órgão Superior         NaN
# ..                     ...         ...
# 61         Data Lançamento         NaN
# 62                     NaN         NaN
# 63                     NaN         NaN
# 64               Exercício         NaN
# 65                     NaN         NaN
#
#                                             DESCRIÇÃO Unnamed: 3
# 0                                                 NaN        NaN
# 1   Código do Órgão Superior responsável pela rece...        NaN
# 2                                                 NaN        NaN
# 3    Nome do Órgão Superior responsável pela receita.        NaN
# 4                                                 NaN        NaN
# ..                                                ...        ...
# ...

# %%
se.reporte(df_diccionario_datos)
# Out:
# La tabla tiene 66 filas y 4 columnas
# La tabla tiene 30 filas duplicadas
#            tipo_variables  contador_total  numero_nulos  porcentaje_nulos  \
# COLUNA             object              16            50             75.76
# Unnamed: 1        float64               0            66            100.00
# DESCRIÇÃO          object              36            30             45.45
# Unnamed: 3         object              14            52             78.79
#
#             valores_unicos  duplicados
# COLUNA                  16          49
# Unnamed: 1               0          65
# DESCRIÇÃO               30          35
# Unnamed: 3              12          53

# %%
df_diccionario_datos = df_diccionario_datos.drop('Unnamed: 1', axis=1)

# %%
df_diccionario_datos
# Out:
#                     COLUNA                                          DESCRIÇÃO  \
# 0                      NaN                                                NaN
# 1    Código Órgão Superior  Código do Órgão Superior responsável pela rece...
# 2                      NaN                                                NaN
# 3                      NaN   Nome do Órgão Superior responsável pela receita.
# 4      Nome Órgão Superior                                                NaN
# ..                     ...                                                ...
# 61         Data Lançamento                      Data de lançamento da receita
# 62                     NaN                                                NaN
# 63                     NaN                                                NaN
# 64               Exercício              Exercício a que se referem os valores
# 65                     NaN                                                NaN
#
#    Unnamed: 3
# 0         NaN
# ...

# %%
df_diccionario_datos.iloc[(4,1)] = df_diccionario_datos.iloc[(3,1)]
df_diccionario_datos.iloc[(3,1)] = np.nan

# %%
df_diccionario_datos
# Out:
#                     COLUNA                                          DESCRIÇÃO  \
# 0                      NaN                                                NaN
# 1    Código Órgão Superior  Código do Órgão Superior responsável pela rece...
# 2                      NaN                                                NaN
# 3                      NaN                                                NaN
# 4      Nome Órgão Superior   Nome do Órgão Superior responsável pela receita.
# ..                     ...                                                ...
# 61         Data Lançamento                      Data de lançamento da receita
# 62                     NaN                                                NaN
# 63                     NaN                                                NaN
# 64               Exercício              Exercício a que se referem os valores
# 65                     NaN                                                NaN
#
#    Unnamed: 3
# 0         NaN
# ...

# %%
indices_eliminar = df_diccionario_datos[df_diccionario_datos.COLUNA.isnull()][df_diccionario_datos.DESCRIÇÃO.isnull()].index
indices_eliminar
# Out:
# Index([ 0,  2,  3,  5,  7,  9, 12, 13, 15, 17, 18, 20, 29, 38, 39, 41, 43, 45,
#        46, 48, 49, 51, 52, 56, 57, 59, 60, 62, 63, 65],
#       dtype='int64')

# %%
df_diccionario_datos = df_diccionario_datos.drop(indices_eliminar, axis=0) # eliminar filas con todo nulos
df_diccionario_datos = df_diccionario_datos.drop_duplicates() #eliminar duplicados

# %%
df_diccionario_datos.loc[(21,'Unnamed: 3')] = df_diccionario_datos.loc[(21,'DESCRIÇÃO')]
df_diccionario_datos.loc[(30,'Unnamed: 3')] = df_diccionario_datos.loc[(30,'DESCRIÇÃO')]

# %%
df_descriptivos_columnas = df_diccionario_datos[df_diccionario_datos.DESCRIÇÃO.notnull()][df_diccionario_datos['Unnamed: 3'].isnull()]

# %%
display(df_descriptivos_columnas[['COLUNA','DESCRIÇÃO']])

diccionario_detalle_descripción={}
for indice,detalle in enumerate(df_descriptivos_columnas.DESCRIÇÃO.items()):
    diccionario_detalle_descripción.update({indice:detalle})

# Diccionario de traducción manual
traducciones = {
    'Código do Órgão Superior responsável pela receita.': 'Código del Órgano Superior responsable de la recaudación.',
    'Nome do Órgão Superior responsável pela receita.': 'Nombre del Órgano Superior responsable de la recaudación.',
    'Código do Órgão Subordinado responsável pela receita.': 'Código del Órgano Subordinado responsable de la recaudación.',
    'Nome do Órgão Subordinado responsável pela receita.': 'Nombre del Órgano Subordinado responsable de la recaudación.',
    'Código da Unidade Gestora responsável pela receita.': 'Código de la Unidad Gestora responsable de la recaudación.',
    'UNIDADE GESTORA (UG) - Unidade Orçamentária ou Administrativa que realiza atos de gestão orçamentária, financeira e/ou patrimonial, cujo titular, em consequência, está sujeito a tomada de contas anual na conformidade do disposto nos artigos 81 e 82 do Decreto-lei nr. 200, de 25 de fevereiro de 1967.': 'UNIDAD GESTORA (UG) - Unidad Presupuestaria o Administrativa que realiza actos de gestión presupuestaria, financiera y/o patrimonial, cuyo titular, en consecuencia, está sujeto a rendir cuentas anuales de acuerdo con lo dispuesto en los artículos 81 y 82 del Decreto-Ley nº 200, de 25 de febrero de 1967.',
    '\xa0Nome da Unidade Gestora responsável pela receita.': 'Nombre de la Unidad Gestora responsable de la recaudación.',
    '\xa0\x93Receitas Correntes\x94 ou \x93Receitas de Capital\x94': '"Ingresos Corrientes" o "Ingresos de Capital"',
    'Detalhamento das categorias econômicas Receitas Correntes e Receitas de Capital, com vistas a identificar a procedência das receitas no momento em que ingressam nos cofres públicos. \xa0': 'Desglose de las categorías económicas de los Ingresos Corrientes y de Capital, con el objetivo de identificar el origen de los ingresos al momento de su ingreso en las arcas públicas.',
    'Para \x93Receitas Correntes\x94:': 'Para "Ingresos Corrientes":',
    'Para \x93Receitas de Capital\x94:': 'Para "Ingresos de Capital":',
    'Nível de classificação vinculado à origem, permite qualificar com maior detalhe o fato gerador das receitas. Por exemplo, dentro da origem \x93Contribuições\x94, identificam-se as espécies \x93Contribuições Sociais\x94, \x93Contribuições Econômicas\x94 e \x93Contribuições para Entidades Privadas de Serviço Social e de Formação Profissional\x94.': 'Nivel de clasificación vinculado al origen, permite detallar con mayor precisión el hecho generador de los ingresos. Por ejemplo, dentro del origen "Contribuciones", se identifican las especies "Contribuciones Sociales", "Contribuciones Económicas" y "Contribuciones a Entidades Privadas de Servicio Social y Formación Profesional".',
    'Detalhamento de outros níveis da receita': 'Desglose de otros niveles de la recaudación',
    'Orçamento inicial da receita atualizado por mudanças na previsão': 'Presupuesto inicial de los ingresos actualizado por cambios en la previsión.',
    'Valor da receita lançada': 'Valor de los ingresos registrados.',
    'Data de lançamento da receita': 'Fecha de registro de la recaudación.',
    'Exercício a que se referem os valores': 'Ejercicio al que se refieren los valores.',
    'A tabela-resumo com os códigos relacionados às\xa0origens\xa0e\xa0espécies\xa0de receitas encontra-se no item 8.1.3. do Manual Técnico de Orçamento.': 'La tabla resumen con los códigos relacionados con los orígenes y especies de ingresos se encuentra en el ítem 8.1.3 del Manual Técnico de Presupuesto.',
    'Valor resultado da fase de arrecadação/recolhimento da receita.': 'Valor resultante de la fase de recaudación/recolecta de los ingresos.',
    'Na fase da arrecadação, é feita a entrega, pelos contribuintes ou devedores, dos valores devidos ao Governo. Os valores são entregues aos agentes arrecadadores ou bancos autorizados.': 'En la fase de recaudación, los contribuyentes o deudores entregan los valores adeudados al Gobierno. Los valores se entregan a los agentes recaudadores o bancos autorizados.',
    'O recolhimento consiste na entrega dos valores arrecadados, pelos agentes arrecadadores ou bancos autorizados, aos cofres públicos, tornando-os disponíveis na conta única do Tesouro Nacional, para uso pelo Governo.':'La recolección consiste en la entrega de los valores recaudados, por los agentes recaudadores o bancos autorizados, a las arcas públicas, poniéndolos a disposición en la cuenta única del Tesoro Nacional, para su uso por parte del Gobierno.',
    'Valor Arrecadado/ Valor Previsto *100': 'Valor Recaudado/Valor Previsto *100'

}

# Crear un nuevo diccionario con las traducciones
diccionario_traducido = {}
for key, value in diccionario_detalle_descripción.items():
    indice, texto = value
    # Buscar la traducción en el diccionario
    texto_traducido = traducciones.get(texto, texto)  # Si no encuentra traducción, mantiene el original
    diccionario_traducido[key] = (indice, texto_traducido)

# Mostrar el diccionario traducido
print(f'El descriptivo de las columnas es:')
for key, value in diccionario_traducido.items():
    print(f"{df_descriptivos_columnas.iloc[key,0]}: {value}")
    print()

print(f'Las categorias de recetas corrientes y recetas de capital son:')
df_categorias_recetas_corrientes_y_capital= df_diccionario_datos[df_diccionario_datos.DESCRIÇÃO.notnull()][df_diccionario_datos['Unnamed: 3'].notnull()]
df_categorias_recetas_corrientes_y_capital[['DESCRIÇÃO','Unnamed: 3']]
# Out:
#                      COLUNA                                          DESCRIÇÃO
# 1     Código Órgão Superior  Código do Órgão Superior responsável pela rece...
# 4       Nome Órgão Superior   Nome do Órgão Superior responsável pela receita.
# 6              Código Órgão  Código do Órgão Subordinado responsável pela r...
# 8                Nome Órgão  Nome do Órgão Subordinado responsável pela rec...
# 10   Código Unidade Gestora  Código da Unidade Gestora responsável pela rec...
# 11                      NaN  UNIDADE GESTORA (UG) - Unidade Orçamentária ou...
# 14     Nome Unidade Gestora   Nome da Unidade Gestora responsável pela rece...
# 16      Categoria Econômica      Receitas Correntes ou Receitas de Capital
# 19                   Origem  Detalhamento das categorias econômicas Receita...
# 40                  Espécie  Nível de classificação vinculado à origem, per...
# 42                      NaN  A tabela-resumo com os códigos relacionados às...
# ...

# %% [markdown]
# # Anális datos año 2013

# %%
se.traducción_columnas(df_datos_2013)

# %%
df_datos_2013
# Out:
#       CÓDIGO_ÓRGANO_SUPERIOR    NOMBRE_ÓRGANO_SUPERIOR  CÓDIGO_ÓRGANO  \
# 0                      63000  Advocacia-Geral da União          63000
# 1                      63000  Advocacia-Geral da União          63000
# 2                      63000  Advocacia-Geral da União          63000
# 3                      63000  Advocacia-Geral da União          63000
# 4                      63000  Advocacia-Geral da União          63000
# ...                      ...                       ...            ...
# 4493                   20000  Presidência da República          20101
# 4494                   20000  Presidência da República          64000
# 4495                   20000  Presidência da República          20101
# 4496                   20000  Presidência da República          20116
# 4497                   20000  Presidência da República          24208
#
#                                           NOMBRE_ÓRGANO  \
# 0     Advocacia-Geral da União - Unidades com víncul...
# ...

# %%
se.reporte(df_datos_2013)
# Out:
# La tabla tiene 4498 filas y 16 columnas
# La tabla tiene 0 filas duplicadas
#                            tipo_variables  contador_total  numero_nulos  \
# CÓDIGO_ÓRGANO_SUPERIOR              int64            4498             0
# NOMBRE_ÓRGANO_SUPERIOR             object            4498             0
# CÓDIGO_ÓRGANO                       int64            4498             0
# NOMBRE_ÓRGANO                      object            4498             0
# CÓDIGO_UNIDAD_GESTORA               int64            4498             0
# NOMBRE_UNIDAD_GESTORA              object            4498             0
# CATEGORÍA_ECONÓMICA                object            4498             0
# ORIGEN_INGRESO                     object            4498             0
# TIPO_INGRESO                       object            4498             0
# DETALLE                            object            4498             0
# VALOR_PREVISTO_ACTUALIZADO         object            4498             0
# ...

# %%
se.conversion_columnas(df_datos_2013)
# Out:
# La tabla tiene 4498 filas y 16 columnas
# La tabla tiene 0 filas duplicadas
#                             tipo_variables  contador_total  numero_nulos  \
# CÓDIGO_ÓRGANO_SUPERIOR              object            4498             0
# NOMBRE_ÓRGANO_SUPERIOR              object            4498             0
# CÓDIGO_ÓRGANO                       object            4498             0
# NOMBRE_ÓRGANO                       object            4498             0
# CÓDIGO_UNIDAD_GESTORA               object            4498             0
# NOMBRE_UNIDAD_GESTORA               object            4498             0
# CATEGORÍA_ECONÓMICA                 object            4498             0
# ORIGEN_INGRESO                      object            4498             0
# TIPO_INGRESO                        object            4498             0
# DETALLE                             object            4498             0
# VALOR_PREVISTO_ACTUALIZADO         float64            4498             0
# ...

# %%
se.analisis_descriptivos_categóricas(df_datos_2013)
# Out:
# Las columnas categóricas son Index(['CÓDIGO_ÓRGANO_SUPERIOR', 'NOMBRE_ÓRGANO_SUPERIOR', 'CÓDIGO_ÓRGANO',
#        'NOMBRE_ÓRGANO', 'CÓDIGO_UNIDAD_GESTORA', 'NOMBRE_UNIDAD_GESTORA',
#        'CATEGORÍA_ECONÓMICA', 'ORIGEN_INGRESO', 'TIPO_INGRESO', 'DETALLE'],
#       dtype='object')
# Algunos ejemplos de filas son:
#      CÓDIGO_ÓRGANO_SUPERIOR                  NOMBRE_ÓRGANO_SUPERIOR  \
# 2469                  26000                  Ministério da Educação
# 724                   25000                  Ministério da Economia
# 2682                  26000                  Ministério da Educação
# 3963                  53000  Ministério do Desenvolvimento Regional
# 2621                  26000                  Ministério da Educação
#
#      CÓDIGO_ÓRGANO                                      NOMBRE_ÓRGANO  \
# 2469         26201                                   Colégio Pedro II
# 724          25000  Ministério da Economia - Unidades com vínculo ...
# ...

# %%
se.analisis_descriptivos_numéricas(df_datos_2013)
# Out:
# Las columnas no categóricas son Index(['VALOR_PREVISTO_ACTUALIZADO', 'VALOR_REGISTRADO', 'VALOR_REALIZADO',
#        'PORCENTAJE_REALIZADO', 'FECHA_REGISTRO', 'AÑO_EJERCICIO'],
#       dtype='object')
# Algunos ejemplos de filas son:
#       VALOR_PREVISTO_ACTUALIZADO  VALOR_REGISTRADO  VALOR_REALIZADO  \
# 2373                        0.00              0.00           719.23
# 874                    302824.00              0.00         24895.70
# 1492                   146282.00              0.00        334957.22
# 4197                  5061321.00              0.00             0.00
# 1219                        0.00              0.00            93.85
#
#       PORCENTAJE_REALIZADO FECHA_REGISTRO  AÑO_EJERCICIO
# 2373                  0.00     2013-12-31           2013
# 874                   8.00     2013-12-31           2013
# 1492                229.00     2013-12-31           2013
# 4197                  0.00     2013-12-31           2013
# ...

# %% [markdown]
# # Anális datos año 2014

# %%
se.traducción_columnas(df_datos_2014)

# %%
df_datos_2014
# Out:
#       CÓDIGO_ÓRGANO_SUPERIOR    NOMBRE_ÓRGANO_SUPERIOR  CÓDIGO_ÓRGANO  \
# 0                      63000  Advocacia-Geral da União          63000
# 1                      63000  Advocacia-Geral da União          63000
# 2                      63000  Advocacia-Geral da União          63000
# 3                      63000  Advocacia-Geral da União          63000
# 4                      63000  Advocacia-Geral da União          63000
# ...                      ...                       ...            ...
# 4548                   20000  Presidência da República          20101
# 4549                   20000  Presidência da República          20101
# 4550                   20000  Presidência da República          20101
# 4551                   20000  Presidência da República          20101
# 4552                   20000  Presidência da República          20101
#
#                                           NOMBRE_ÓRGANO  \
# 0     Advocacia-Geral da União - Unidades com víncul...
# ...

# %%
se.reporte(df_datos_2014)
# Out:
# La tabla tiene 4553 filas y 16 columnas
# La tabla tiene 0 filas duplicadas
#                            tipo_variables  contador_total  numero_nulos  \
# CÓDIGO_ÓRGANO_SUPERIOR              int64            4553             0
# NOMBRE_ÓRGANO_SUPERIOR             object            4553             0
# CÓDIGO_ÓRGANO                       int64            4553             0
# NOMBRE_ÓRGANO                      object            4553             0
# CÓDIGO_UNIDAD_GESTORA               int64            4553             0
# NOMBRE_UNIDAD_GESTORA              object            4553             0
# CATEGORÍA_ECONÓMICA                object            4553             0
# ORIGEN_INGRESO                     object            4553             0
# TIPO_INGRESO                       object            4553             0
# DETALLE                            object            4553             0
# VALOR_PREVISTO_ACTUALIZADO         object            4553             0
# ...

# %%
se.conversion_columnas(df_datos_2014)
# Out:
# La tabla tiene 4553 filas y 16 columnas
# La tabla tiene 0 filas duplicadas
#                             tipo_variables  contador_total  numero_nulos  \
# CÓDIGO_ÓRGANO_SUPERIOR              object            4553             0
# NOMBRE_ÓRGANO_SUPERIOR              object            4553             0
# CÓDIGO_ÓRGANO                       object            4553             0
# NOMBRE_ÓRGANO                       object            4553             0
# CÓDIGO_UNIDAD_GESTORA               object            4553             0
# NOMBRE_UNIDAD_GESTORA               object            4553             0
# CATEGORÍA_ECONÓMICA                 object            4553             0
# ORIGEN_INGRESO                      object            4553             0
# TIPO_INGRESO                        object            4553             0
# DETALLE                             object            4553             0
# VALOR_PREVISTO_ACTUALIZADO         float64            4553             0
# ...

# %%
se.analisis_descriptivos_categóricas(df_datos_2014)
# Out:
# Las columnas categóricas son Index(['CÓDIGO_ÓRGANO_SUPERIOR', 'NOMBRE_ÓRGANO_SUPERIOR', 'CÓDIGO_ÓRGANO',
#        'NOMBRE_ÓRGANO', 'CÓDIGO_UNIDAD_GESTORA', 'NOMBRE_UNIDAD_GESTORA',
#        'CATEGORÍA_ECONÓMICA', 'ORIGEN_INGRESO', 'TIPO_INGRESO', 'DETALLE'],
#       dtype='object')
# Algunos ejemplos de filas son:
#      CÓDIGO_ÓRGANO_SUPERIOR  NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 755                   25000  Ministério da Economia         25000
# 714                   25000  Ministério da Economia         25000
# 1710                  26000  Ministério da Educação         26241
# 3160                  26000  Ministério da Educação         26281
# 1177                  25000  Ministério da Economia         37904
#
#                                           NOMBRE_ÓRGANO CÓDIGO_UNIDAD_GESTORA  \
# 755   Ministério da Economia - Unidades com vínculo ...                170013
# 714   Ministério da Economia - Unidades com vínculo ...                170013
# ...

# %%
se.analisis_descriptivos_numéricas(df_datos_2014)
# Out:
# Las columnas no categóricas son Index(['VALOR_PREVISTO_ACTUALIZADO', 'VALOR_REGISTRADO', 'VALOR_REALIZADO',
#        'PORCENTAJE_REALIZADO', 'FECHA_REGISTRO', 'AÑO_EJERCICIO'],
#       dtype='object')
# Algunos ejemplos de filas son:
#       VALOR_PREVISTO_ACTUALIZADO  VALOR_REGISTRADO  VALOR_REALIZADO  \
# 2950                        0.00              0.00        143102.30
# 1769                        0.00              0.00            16.00
# 2885                        0.00              0.00           300.00
# 2720                415916187.00              0.00     263649254.50
# 2019                  1000000.00              0.00        100000.00
#
#       PORCENTAJE_REALIZADO FECHA_REGISTRO  AÑO_EJERCICIO
# 2950                  0.00     2014-12-31           2014
# 1769                  0.00     2014-12-31           2014
# 2885                  0.00     2014-12-31           2014
# 2720                 63.00     2014-12-31           2014
# ...

# %% [markdown]
# # Análisis datos año 2015

# %%
se.traducción_columnas(df_datos_2015)

# %%
se.reporte(df_datos_2015)
# Out:
# La tabla tiene 4523 filas y 16 columnas
# La tabla tiene 0 filas duplicadas
#                            tipo_variables  contador_total  numero_nulos  \
# CÓDIGO_ÓRGANO_SUPERIOR              int64            4523             0
# NOMBRE_ÓRGANO_SUPERIOR             object            4523             0
# CÓDIGO_ÓRGANO                       int64            4523             0
# NOMBRE_ÓRGANO                      object            4523             0
# CÓDIGO_UNIDAD_GESTORA               int64            4523             0
# NOMBRE_UNIDAD_GESTORA              object            4523             0
# CATEGORÍA_ECONÓMICA                object            4523             0
# ORIGEN_INGRESO                     object            4523             0
# TIPO_INGRESO                       object            4523             0
# DETALLE                            object            4523             0
# VALOR_PREVISTO_ACTUALIZADO         object            4523             0
# ...

# %%
se.conversion_columnas(df_datos_2015)
# Out:
# La tabla tiene 4523 filas y 16 columnas
# La tabla tiene 0 filas duplicadas
#                             tipo_variables  contador_total  numero_nulos  \
# CÓDIGO_ÓRGANO_SUPERIOR              object            4523             0
# NOMBRE_ÓRGANO_SUPERIOR              object            4523             0
# CÓDIGO_ÓRGANO                       object            4523             0
# NOMBRE_ÓRGANO                       object            4523             0
# CÓDIGO_UNIDAD_GESTORA               object            4523             0
# NOMBRE_UNIDAD_GESTORA               object            4523             0
# CATEGORÍA_ECONÓMICA                 object            4523             0
# ORIGEN_INGRESO                      object            4523             0
# TIPO_INGRESO                        object            4523             0
# DETALLE                             object            4523             0
# VALOR_PREVISTO_ACTUALIZADO         float64            4523             0
# ...

# %%
se.analisis_descriptivos_categóricas(df_datos_2015)
# Out:
# Las columnas categóricas son Index(['CÓDIGO_ÓRGANO_SUPERIOR', 'NOMBRE_ÓRGANO_SUPERIOR', 'CÓDIGO_ÓRGANO',
#        'NOMBRE_ÓRGANO', 'CÓDIGO_UNIDAD_GESTORA', 'NOMBRE_UNIDAD_GESTORA',
#        'CATEGORÍA_ECONÓMICA', 'ORIGEN_INGRESO', 'TIPO_INGRESO', 'DETALLE'],
#       dtype='object')
# Algunos ejemplos de filas son:
#      CÓDIGO_ÓRGANO_SUPERIOR                         NOMBRE_ÓRGANO_SUPERIOR  \
# 2135                  26000                         Ministério da Educação
# 318                   24000  Ministério da Ciência, Tecnologia, Inovações
# 381                   52000                           Ministério da Defesa
# 1525                  26000                         Ministério da Educação
# 2928                  26000                         Ministério da Educação
#
#      CÓDIGO_ÓRGANO                                      NOMBRE_ÓRGANO  \
# 2135         26246             Universidade Federal de Santa Catarina
# ...

# %%
se.analisis_descriptivos_numéricas(df_datos_2015)
# Out:
# Las columnas no categóricas son Index(['VALOR_PREVISTO_ACTUALIZADO', 'VALOR_REGISTRADO', 'VALOR_REALIZADO',
#        'PORCENTAJE_REALIZADO', 'FECHA_REGISTRO', 'AÑO_EJERCICIO'],
#       dtype='object')
# Algunos ejemplos de filas son:
#       VALOR_PREVISTO_ACTUALIZADO  VALOR_REGISTRADO  VALOR_REALIZADO  \
# 2577                        0.00              0.00        135328.32
# 2121                   135794.00              0.00             0.00
# 1353                    20470.00              0.00             0.00
# 2988                     7922.00              0.00             0.00
# 2418                 10388481.00              0.00      10170728.53
#
#       PORCENTAJE_REALIZADO FECHA_REGISTRO  AÑO_EJERCICIO
# 2577                  0.00     2015-12-31           2015
# 2121                  0.00     2015-12-31           2015
# 1353                  0.00     2015-12-31           2015
# 2988                  0.00     2015-12-31           2015
# ...

# %% [markdown]
# # Análisis datos años 2016

# %%
se.traducción_columnas(df_datos_2016)

# %%
df_datos_2016
# Out:
#         CÓDIGO_ÓRGANO_SUPERIOR    NOMBRE_ÓRGANO_SUPERIOR  CÓDIGO_ÓRGANO  \
# 0                        63000  Advocacia-Geral da União          63000
# 1                        63000  Advocacia-Geral da União          63000
# 2                        63000  Advocacia-Geral da União          63000
# 3                        63000  Advocacia-Geral da União          63000
# 4                        63000  Advocacia-Geral da União          63000
# ...                        ...                       ...            ...
# 194528                   20000  Presidência da República          69000
# 194529                   20000  Presidência da República          69000
# 194530                   20000  Presidência da República          69000
# 194531                   20000  Presidência da República          69000
# 194532                   20000  Presidência da República          69000
#
#                                             NOMBRE_ÓRGANO  \
# ...

# %%
se.reporte(df_datos_2016)
# Out:
# La tabla tiene 194533 filas y 16 columnas
# La tabla tiene 0 filas duplicadas
#                            tipo_variables  contador_total  numero_nulos  \
# CÓDIGO_ÓRGANO_SUPERIOR              int64          194533             0
# NOMBRE_ÓRGANO_SUPERIOR             object          194533             0
# CÓDIGO_ÓRGANO                       int64          194533             0
# NOMBRE_ÓRGANO                      object          194533             0
# CÓDIGO_UNIDAD_GESTORA               int64          194533             0
# NOMBRE_UNIDAD_GESTORA              object          194533             0
# CATEGORÍA_ECONÓMICA                object          194533             0
# ORIGEN_INGRESO                     object          194533             0
# TIPO_INGRESO                       object          194533             0
# DETALLE                            object          194533             0
# VALOR_PREVISTO_ACTUALIZADO         object          194533             0
# ...

# %%
se.conversion_columnas(df_datos_2016)
# Out:
# La tabla tiene 194533 filas y 16 columnas
# La tabla tiene 0 filas duplicadas
#                             tipo_variables  contador_total  numero_nulos  \
# CÓDIGO_ÓRGANO_SUPERIOR              object          194533             0
# NOMBRE_ÓRGANO_SUPERIOR              object          194533             0
# CÓDIGO_ÓRGANO                       object          194533             0
# NOMBRE_ÓRGANO                       object          194533             0
# CÓDIGO_UNIDAD_GESTORA               object          194533             0
# NOMBRE_UNIDAD_GESTORA               object          194533             0
# CATEGORÍA_ECONÓMICA                 object          194533             0
# ORIGEN_INGRESO                      object          194533             0
# TIPO_INGRESO                        object          194533             0
# DETALLE                             object          194533             0
# VALOR_PREVISTO_ACTUALIZADO         float64          194533             0
# ...

# %%
se.analisis_descriptivos_categóricas(df_datos_2016)
# Out:
# Las columnas categóricas son Index(['CÓDIGO_ÓRGANO_SUPERIOR', 'NOMBRE_ÓRGANO_SUPERIOR', 'CÓDIGO_ÓRGANO',
#        'NOMBRE_ÓRGANO', 'CÓDIGO_UNIDAD_GESTORA', 'NOMBRE_UNIDAD_GESTORA',
#        'CATEGORÍA_ECONÓMICA', 'ORIGEN_INGRESO', 'TIPO_INGRESO', 'DETALLE'],
#       dtype='object')
# Algunos ejemplos de filas son:
#        CÓDIGO_ÓRGANO_SUPERIOR       NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 125806                  26000       Ministério da Educação         26272
# 182474                  44000  Ministério do Meio Ambiente         44207
# 49842                   25000       Ministério da Economia         25201
# 72969                   26000       Ministério da Educação         26244
# 79299                   26000       Ministério da Educação         26243
#
#                                             NOMBRE_ÓRGANO  \
# 125806                  Fundação Universidade do Maranhão
# 182474  Instituto Chico Mendes de Conservação da Biodi...
# ...

# %%
se.analisis_descriptivos_numéricas(df_datos_2016)
# Out:
# Las columnas no categóricas son Index(['VALOR_PREVISTO_ACTUALIZADO', 'VALOR_REGISTRADO', 'VALOR_REALIZADO',
#        'PORCENTAJE_REALIZADO', 'FECHA_REGISTRO', 'AÑO_EJERCICIO'],
#       dtype='object')
# Algunos ejemplos de filas son:
#         VALOR_PREVISTO_ACTUALIZADO  VALOR_REGISTRADO  VALOR_REALIZADO  \
# 158956                        0.00              0.00           227.10
# 77969                         0.00              0.00          1470.00
# 13711                         0.00              0.00          3495.18
# 57490                         0.00              0.00            54.00
# 119310                        0.00              0.00         26649.52
#
#         PORCENTAJE_REALIZADO FECHA_REGISTRO  AÑO_EJERCICIO
# 158956                  0.00     2016-09-02           2016
# 77969                   0.00     2016-11-25           2016
# 13711                   0.00     2016-07-01           2016
# 57490                   0.00     2016-03-09           2016
# ...

# %%
df_datos_2016[df_datos_2016.FECHA_REGISTRO.isnull()]
# Out:
#        CÓDIGO_ÓRGANO_SUPERIOR                         NOMBRE_ÓRGANO_SUPERIOR  \
# 18141                   24000  Ministério da Ciência, Tecnologia, Inovações
# 37397                   25000                         Ministério da Economia
# 37458                   25000                         Ministério da Economia
# 38173                   25000                         Ministério da Economia
# 38403                   25000                         Ministério da Economia
# ...                       ...                                            ...
# 162740                  41000                    Ministério das Comunicações
# 171364                  32000                  Ministério de Minas e Energia
# 172316                  32000                  Ministério de Minas e Energia
# 186873                  44000                    Ministério do Meio Ambiente
# 189917                  54000                          Ministério do Turismo
#
# ...

# %%
df_datos_2016[df_datos_2016.index>18139]
# Out:
#        CÓDIGO_ÓRGANO_SUPERIOR                         NOMBRE_ÓRGANO_SUPERIOR  \
# 18140                   24000  Ministério da Ciência, Tecnologia, Inovações
# 18141                   24000  Ministério da Ciência, Tecnologia, Inovações
# 18142                   24000  Ministério da Ciência, Tecnologia, Inovações
# 18143                   24000  Ministério da Ciência, Tecnologia, Inovações
# 18144                   24000  Ministério da Ciência, Tecnologia, Inovações
# ...                       ...                                            ...
# 194528                  20000                       Presidência da República
# 194529                  20000                       Presidência da República
# 194530                  20000                       Presidência da República
# 194531                  20000                       Presidência da República
# 194532                  20000                       Presidência da República
#
# ...

# %% [markdown]
# # Análisis datos año 2017

# %%
se.traducción_columnas(df_datos_2017)

# %%
df_datos_2017.sample(5)
# Out:
#         CÓDIGO_ÓRGANO_SUPERIOR                         NOMBRE_ÓRGANO_SUPERIOR  \
# 111668                   26000                         Ministério da Educação
# 43632                    25000                         Ministério da Economia
# 165424                   35000             Ministério das Relações Exteriores
# 152324                   36000                            Ministério da Saúde
# 18394                    24000  Ministério da Ciência, Tecnologia, Inovações
#
#         CÓDIGO_ÓRGANO                                      NOMBRE_ÓRGANO  \
# 111668          26285  Fundação Universidade Federal de São João Del-Rei
# 43632           37202                Instituto Nacional do Seguro Social
# 165424          35000  Ministério das Relações Exteriores - Unidades ...
# 152324          36000  Ministério da Saúde - Unidades com vínculo direto
# 18394           24901  Fundo Nacional de Desenvolvimento Científico e...
#
# ...

# %%
se.reporte(df_datos_2017)
# Out:
# La tabla tiene 190479 filas y 16 columnas
# La tabla tiene 0 filas duplicadas
#                            tipo_variables  contador_total  numero_nulos  \
# CÓDIGO_ÓRGANO_SUPERIOR              int64          190479             0
# NOMBRE_ÓRGANO_SUPERIOR             object          190479             0
# CÓDIGO_ÓRGANO                       int64          190479             0
# NOMBRE_ÓRGANO                      object          190479             0
# CÓDIGO_UNIDAD_GESTORA               int64          190479             0
# NOMBRE_UNIDAD_GESTORA              object          190479             0
# CATEGORÍA_ECONÓMICA                object          190479             0
# ORIGEN_INGRESO                     object          190479             0
# TIPO_INGRESO                       object          190479             0
# DETALLE                            object          190479             0
# VALOR_PREVISTO_ACTUALIZADO         object          190479             0
# ...

# %%
se.conversion_columnas(df_datos_2017)
# Out:
# La tabla tiene 190479 filas y 16 columnas
# La tabla tiene 0 filas duplicadas
#                             tipo_variables  contador_total  numero_nulos  \
# CÓDIGO_ÓRGANO_SUPERIOR              object          190479             0
# NOMBRE_ÓRGANO_SUPERIOR              object          190479             0
# CÓDIGO_ÓRGANO                       object          190479             0
# NOMBRE_ÓRGANO                       object          190479             0
# CÓDIGO_UNIDAD_GESTORA               object          190479             0
# NOMBRE_UNIDAD_GESTORA               object          190479             0
# CATEGORÍA_ECONÓMICA                 object          190479             0
# ORIGEN_INGRESO                      object          190479             0
# TIPO_INGRESO                        object          190479             0
# DETALLE                             object          190479             0
# VALOR_PREVISTO_ACTUALIZADO         float64          190479             0
# ...

# %%
se.analisis_descriptivos_categóricas(df_datos_2017)
# Out:
# Las columnas categóricas son Index(['CÓDIGO_ÓRGANO_SUPERIOR', 'NOMBRE_ÓRGANO_SUPERIOR', 'CÓDIGO_ÓRGANO',
#        'NOMBRE_ÓRGANO', 'CÓDIGO_UNIDAD_GESTORA', 'NOMBRE_UNIDAD_GESTORA',
#        'CATEGORÍA_ECONÓMICA', 'ORIGEN_INGRESO', 'TIPO_INGRESO', 'DETALLE'],
#       dtype='object')
# Algunos ejemplos de filas son:
#        CÓDIGO_ÓRGANO_SUPERIOR                         NOMBRE_ÓRGANO_SUPERIOR  \
# 7998                    22000  Ministério da Agricultura, Pecuária e Abastec
# 27131                   52000                           Ministério da Defesa
# 165602                  35000             Ministério das Relações Exteriores
# 45817                   25000                         Ministério da Economia
# 95789                   26000                         Ministério da Educação
#
#        CÓDIGO_ÓRGANO                                      NOMBRE_ÓRGANO  \
# 7998           22905               Fundo de Defesa da Economia Cafeeira
# ...

# %%
se.analisis_descriptivos_numéricas(df_datos_2017)
# Out:
# Las columnas no categóricas son Index(['VALOR_PREVISTO_ACTUALIZADO', 'VALOR_REGISTRADO', 'VALOR_REALIZADO',
#        'PORCENTAJE_REALIZADO', 'FECHA_REGISTRO', 'AÑO_EJERCICIO'],
#       dtype='object')
# Algunos ejemplos de filas son:
#         VALOR_PREVISTO_ACTUALIZADO  VALOR_REGISTRADO  VALOR_REALIZADO  \
# 126376                        0.00              0.00           307.00
# 28724                         0.00              0.00        143599.49
# 73042                         0.00              0.00          5366.32
# 95165                         0.00              0.00           705.00
# 62763                         0.00              0.00         14092.01
#
#         PORCENTAJE_REALIZADO FECHA_REGISTRO  AÑO_EJERCICIO
# 126376                  0.00     2017-10-04           2017
# 28724                   0.00     2017-06-29           2017
# 73042                   0.00     2017-10-23           2017
# 95165                   0.00     2017-06-29           2017
# ...

# %%
df_datos_2017[df_datos_2017.FECHA_REGISTRO.isnull()]
# Out:
#        CÓDIGO_ÓRGANO_SUPERIOR                         NOMBRE_ÓRGANO_SUPERIOR  \
# 17262                   24000  Ministério da Ciência, Tecnologia, Inovações
# 36136                   25000                         Ministério da Economia
# 36570                   25000                         Ministério da Economia
# 36611                   25000                         Ministério da Economia
# 37932                   25000                         Ministério da Economia
# ...                       ...                                            ...
# 160937                  41000                    Ministério das Comunicações
# 170022                  32000                  Ministério de Minas e Energia
# 170189                  32000                  Ministério de Minas e Energia
# 183381                  44000                    Ministério do Meio Ambiente
# 186669                  54000                          Ministério do Turismo
#
# ...

# %% [markdown]
# # Análisis datos año 2018

# %%
se.traducción_columnas(df_datos_2018)

# %%
df_datos_2018.sample(5)
# Out:
#        CÓDIGO_ÓRGANO_SUPERIOR                         NOMBRE_ÓRGANO_SUPERIOR  \
# 76091                   26000                         Ministério da Educação
# 80016                   26000                         Ministério da Educação
# 51821                   25000                         Ministério da Economia
# 66748                   26000                         Ministério da Educação
# 4235                    22000  Ministério da Agricultura, Pecuária e Abastec
#
#        CÓDIGO_ÓRGANO                                      NOMBRE_ÓRGANO  \
# 76091          26233                      Universidade Federal do Ceará
# 80016          26250                    Universidade Federal de Roraima
# 51821          25000  Ministério da Economia - Unidades com vínculo ...
# 66748          26263                     Universidade Federal de Lavras
# 4235           22202        Empresa Brasileira de Pesquisa Agropecuária
#
# ...

# %%
se.reporte(df_datos_2018)
# Out:
# La tabla tiene 173944 filas y 16 columnas
# La tabla tiene 0 filas duplicadas
#                            tipo_variables  contador_total  numero_nulos  \
# CÓDIGO_ÓRGANO_SUPERIOR              int64          173944             0
# NOMBRE_ÓRGANO_SUPERIOR             object          173944             0
# CÓDIGO_ÓRGANO                       int64          173944             0
# NOMBRE_ÓRGANO                      object          173944             0
# CÓDIGO_UNIDAD_GESTORA               int64          173944             0
# NOMBRE_UNIDAD_GESTORA              object          173944             0
# CATEGORÍA_ECONÓMICA                object          173944             0
# ORIGEN_INGRESO                     object          173944             0
# TIPO_INGRESO                       object          173944             0
# DETALLE                            object          173944             0
# VALOR_PREVISTO_ACTUALIZADO         object          173944             0
# ...

# %%
se.conversion_columnas(df_datos_2018)
# Out:
# La tabla tiene 173944 filas y 16 columnas
# La tabla tiene 0 filas duplicadas
#                             tipo_variables  contador_total  numero_nulos  \
# CÓDIGO_ÓRGANO_SUPERIOR              object          173944             0
# NOMBRE_ÓRGANO_SUPERIOR              object          173944             0
# CÓDIGO_ÓRGANO                       object          173944             0
# NOMBRE_ÓRGANO                       object          173944             0
# CÓDIGO_UNIDAD_GESTORA               object          173944             0
# NOMBRE_UNIDAD_GESTORA               object          173944             0
# CATEGORÍA_ECONÓMICA                 object          173944             0
# ORIGEN_INGRESO                      object          173944             0
# TIPO_INGRESO                        object          173944             0
# DETALLE                             object          173944             0
# VALOR_PREVISTO_ACTUALIZADO         float64          173944             0
# ...

# %%
se.analisis_descriptivos_categóricas(df_datos_2018)
# Out:
# Las columnas categóricas son Index(['CÓDIGO_ÓRGANO_SUPERIOR', 'NOMBRE_ÓRGANO_SUPERIOR', 'CÓDIGO_ÓRGANO',
#        'NOMBRE_ÓRGANO', 'CÓDIGO_UNIDAD_GESTORA', 'NOMBRE_UNIDAD_GESTORA',
#        'CATEGORÍA_ECONÓMICA', 'ORIGEN_INGRESO', 'TIPO_INGRESO', 'DETALLE'],
#       dtype='object')
# Algunos ejemplos de filas son:
#        CÓDIGO_ÓRGANO_SUPERIOR  NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 89207                   26000  Ministério da Educação         26236
# 58880                   25000  Ministério da Economia         25000
# 85982                   26000  Ministério da Educação         26271
# 116585                  26000  Ministério da Educação         26241
# 114210                  26000  Ministério da Educação         26418
#
#                                             NOMBRE_ÓRGANO  \
# 89207                     Universidade Federal Fluminense
# 58880   Ministério da Economia - Unidades com vínculo ...
# 85982                   Fundação Universidade de Brasília
# ...

# %%
se.analisis_descriptivos_numéricas(df_datos_2018)
# Out:
# Las columnas no categóricas son Index(['VALOR_PREVISTO_ACTUALIZADO', 'VALOR_REGISTRADO', 'VALOR_REALIZADO',
#        'PORCENTAJE_REALIZADO', 'FECHA_REGISTRO', 'AÑO_EJERCICIO'],
#       dtype='object')
# Algunos ejemplos de filas son:
#         VALOR_PREVISTO_ACTUALIZADO  VALOR_REGISTRADO  VALOR_REALIZADO  \
# 94267                         0.00              0.00          5578.00
# 90169                         0.00              0.00          4247.93
# 27199                         0.00              0.00         33459.54
# 74436                         0.00              0.00           660.64
# 122171                        0.00              0.00          9098.00
#
#         PORCENTAJE_REALIZADO FECHA_REGISTRO  AÑO_EJERCICIO
# 94267                   0.00     2018-08-31           2018
# 90169                   0.00     2018-06-29           2018
# 27199                   0.00     2018-11-14           2018
# 74436                   0.00     2018-06-20           2018
# ...

# %%
df_datos_2018[df_datos_2018.FECHA_REGISTRO.isnull()][df_datos_2018.VALOR_REALIZADO==0][df_datos_2018.VALOR_PREVISTO_ACTUALIZADO==0]
# Out:
#        CÓDIGO_ÓRGANO_SUPERIOR                         NOMBRE_ÓRGANO_SUPERIOR  \
# 8310                    24000  Ministério da Ciência, Tecnologia, Inovações
# 29204                   25000                         Ministério da Economia
# 29297                   25000                         Ministério da Economia
# 29666                   25000                         Ministério da Economia
# 29723                   25000                         Ministério da Economia
# ...                       ...                                            ...
# 157405                  32000                  Ministério de Minas e Energia
# 164643                  44000                    Ministério do Meio Ambiente
# 164646                  44000                    Ministério do Meio Ambiente
# 168923                  44000                    Ministério do Meio Ambiente
# 171452                  54000                          Ministério do Turismo
#
# ...

# %% [markdown]
# # Análisis datos año 2019

# %%
se.traducción_columnas(df_datos_2019)

# %%
df_datos_2019.sample(5)
# Out:
#         CÓDIGO_ÓRGANO_SUPERIOR  NOMBRE_ÓRGANO_SUPERIOR  CÓDIGO_ÓRGANO  \
# 67158                    26000  Ministério da Educação          26443
# 96375                    26000  Ministério da Educação          26241
# 100399                   26000  Ministério da Educação          26436
# 36885                    25000  Ministério da Economia          38901
# 93579                    26000  Ministério da Educação          26239
#
#                                       NOMBRE_ÓRGANO  CÓDIGO_UNIDAD_GESTORA  \
# 67158   Empresa Brasileira de Serviços Hospitalares                 155007
# 96375                Universidade Federal do Paraná                 153079
# 100399          Instituto Federal Sul-rio-grandense                 158126
# 36885                Fundo de Amparo ao Trabalhador                 380910
# 93579                  Universidade Federal do Pará                 153063
#
#                                 NOMBRE_UNIDAD_GESTORA CATEGORÍA_ECONÓMICA  \
# ...

# %%
se.reporte(df_datos_2019)
# Out:
# La tabla tiene 176828 filas y 16 columnas
# La tabla tiene 0 filas duplicadas
#                            tipo_variables  contador_total  numero_nulos  \
# CÓDIGO_ÓRGANO_SUPERIOR              int64          176828             0
# NOMBRE_ÓRGANO_SUPERIOR             object          176828             0
# CÓDIGO_ÓRGANO                       int64          176828             0
# NOMBRE_ÓRGANO                      object          176828             0
# CÓDIGO_UNIDAD_GESTORA               int64          176828             0
# NOMBRE_UNIDAD_GESTORA              object          176828             0
# CATEGORÍA_ECONÓMICA                object          176828             0
# ORIGEN_INGRESO                     object          176828             0
# TIPO_INGRESO                       object          176828             0
# DETALLE                            object          176828             0
# VALOR_PREVISTO_ACTUALIZADO         object          176828             0
# ...

# %%
se.conversion_columnas(df_datos_2019)
# Out:
# La tabla tiene 176828 filas y 16 columnas
# La tabla tiene 0 filas duplicadas
#                             tipo_variables  contador_total  numero_nulos  \
# CÓDIGO_ÓRGANO_SUPERIOR              object          176828             0
# NOMBRE_ÓRGANO_SUPERIOR              object          176828             0
# CÓDIGO_ÓRGANO                       object          176828             0
# NOMBRE_ÓRGANO                       object          176828             0
# CÓDIGO_UNIDAD_GESTORA               object          176828             0
# NOMBRE_UNIDAD_GESTORA               object          176828             0
# CATEGORÍA_ECONÓMICA                 object          176828             0
# ORIGEN_INGRESO                      object          176828             0
# TIPO_INGRESO                        object          176828             0
# DETALLE                             object          176828             0
# VALOR_PREVISTO_ACTUALIZADO         float64          176828             0
# ...

# %%
se.analisis_descriptivos_categóricas(df_datos_2019)
# Out:
# Las columnas categóricas son Index(['CÓDIGO_ÓRGANO_SUPERIOR', 'NOMBRE_ÓRGANO_SUPERIOR', 'CÓDIGO_ÓRGANO',
#        'NOMBRE_ÓRGANO', 'CÓDIGO_UNIDAD_GESTORA', 'NOMBRE_UNIDAD_GESTORA',
#        'CATEGORÍA_ECONÓMICA', 'ORIGEN_INGRESO', 'TIPO_INGRESO', 'DETALLE'],
#       dtype='object')
# Algunos ejemplos de filas son:
#        CÓDIGO_ÓRGANO_SUPERIOR                         NOMBRE_ÓRGANO_SUPERIOR  \
# 171215                  44000                    Ministério do Meio Ambiente
# 3406                    22000  Ministério da Agricultura, Pecuária e Abastec
# 53915                   25000                         Ministério da Economia
# 37603                   25000                         Ministério da Economia
# 68246                   26000                         Ministério da Educação
#
#        CÓDIGO_ÓRGANO                                      NOMBRE_ÓRGANO  \
# 171215         20701  Instituto Brasileiro do Meio Ambiente e dos Re...
# ...

# %%
se.analisis_descriptivos_numéricas(df_datos_2019)
# Out:
# Las columnas no categóricas son Index(['VALOR_PREVISTO_ACTUALIZADO', 'VALOR_REGISTRADO', 'VALOR_REALIZADO',
#        'PORCENTAJE_REALIZADO', 'FECHA_REGISTRO', 'AÑO_EJERCICIO'],
#       dtype='object')
# Algunos ejemplos de filas son:
#         VALOR_PREVISTO_ACTUALIZADO  VALOR_REGISTRADO  VALOR_REALIZADO  \
# 25821                         0.00              0.00       6588922.80
# 142262                        0.00              0.00         11813.41
# 79599                         0.00              0.00          3271.37
# 161616                        0.00              0.00         85645.87
# 26869                         0.00              0.00             1.75
#
#         PORCENTAJE_REALIZADO FECHA_REGISTRO  AÑO_EJERCICIO
# 25821                   0.00     2019-08-13           2019
# 142262                  0.00     2019-01-03           2019
# 79599                   0.00     2019-12-05           2019
# 161616                  0.00     2019-03-21           2019
# ...

# %%
df_datos_2019[df_datos_2019.FECHA_REGISTRO.isnull()][df_datos_2019.VALOR_REALIZADO==0][df_datos_2019.VALOR_PREVISTO_ACTUALIZADO==0]
# Out:
#        CÓDIGO_ÓRGANO_SUPERIOR         NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 30357                   25000         Ministério da Economia         25000
# 30663                   25000         Ministério da Economia         25000
# 31910                   25000         Ministério da Economia         25000
# 32038                   25000         Ministério da Economia         25000
# 32130                   25000         Ministério da Economia         25000
# ...                       ...                            ...           ...
# 159602                  32000  Ministério de Minas e Energia         32210
# 159921                  32000  Ministério de Minas e Energia         32210
# 159993                  32000  Ministério de Minas e Energia         32210
# 160099                  32000  Ministério de Minas e Energia         32210
# 174999                  54000          Ministério do Turismo         20203
#
#                                             NOMBRE_ÓRGANO  \
# ...

# %% [markdown]
# # Análisis datos año 2020

# %%
se.traducción_columnas(df_datos_2020)

# %%
df_datos_2020.sample(5)
# Out:
#         CÓDIGO_ÓRGANO_SUPERIOR         NOMBRE_ÓRGANO_SUPERIOR  CÓDIGO_ÓRGANO  \
# 126136                   32000  Ministério de Minas e Energia          32396
# 102378                   26000         Ministério da Educação          26280
# 85789                    26000         Ministério da Educação          26264
# 121775                   41000    Ministério das Comunicações          41232
# 60532                    25000         Ministério da Economia          25208
#
#                                             NOMBRE_ÓRGANO  \
# 126136                      Agência Nacional de Mineração
# 102378        Fundação Universidade Federal de São Carlos
# 85789            Universidade Federal Rural do Semi-Árido
# 121775  Fundo de Universalização dos Serviços de Telec...
# 60532                Superintendência de Seguros Privados
#
#         CÓDIGO_UNIDAD_GESTORA                          NOMBRE_UNIDAD_GESTORA  \
# ...

# %%
se.reporte(df_datos_2020)
# Out:
# La tabla tiene 142348 filas y 16 columnas
# La tabla tiene 0 filas duplicadas
#                            tipo_variables  contador_total  numero_nulos  \
# CÓDIGO_ÓRGANO_SUPERIOR              int64          142348             0
# NOMBRE_ÓRGANO_SUPERIOR             object          142348             0
# CÓDIGO_ÓRGANO                       int64          142348             0
# NOMBRE_ÓRGANO                      object          142348             0
# CÓDIGO_UNIDAD_GESTORA               int64          142348             0
# NOMBRE_UNIDAD_GESTORA              object          142348             0
# CATEGORÍA_ECONÓMICA                object          142348             0
# ORIGEN_INGRESO                     object          142348             0
# TIPO_INGRESO                       object          142348             0
# DETALLE                            object          142348             0
# VALOR_PREVISTO_ACTUALIZADO         object          142348             0
# ...

# %%
se.conversion_columnas(df_datos_2020)
# Out:
# La tabla tiene 142348 filas y 16 columnas
# La tabla tiene 0 filas duplicadas
#                             tipo_variables  contador_total  numero_nulos  \
# CÓDIGO_ÓRGANO_SUPERIOR              object          142348             0
# NOMBRE_ÓRGANO_SUPERIOR              object          142348             0
# CÓDIGO_ÓRGANO                       object          142348             0
# NOMBRE_ÓRGANO                       object          142348             0
# CÓDIGO_UNIDAD_GESTORA               object          142348             0
# NOMBRE_UNIDAD_GESTORA               object          142348             0
# CATEGORÍA_ECONÓMICA                 object          142348             0
# ORIGEN_INGRESO                      object          142348             0
# TIPO_INGRESO                        object          142348             0
# DETALLE                             object          142348             0
# VALOR_PREVISTO_ACTUALIZADO         float64          142348             0
# ...

# %%
se.analisis_descriptivos_categóricas(df_datos_2020)
# Out:
# Las columnas categóricas son Index(['CÓDIGO_ÓRGANO_SUPERIOR', 'NOMBRE_ÓRGANO_SUPERIOR', 'CÓDIGO_ÓRGANO',
#        'NOMBRE_ÓRGANO', 'CÓDIGO_UNIDAD_GESTORA', 'NOMBRE_UNIDAD_GESTORA',
#        'CATEGORÍA_ECONÓMICA', 'ORIGEN_INGRESO', 'TIPO_INGRESO', 'DETALLE'],
#       dtype='object')
# Algunos ejemplos de filas son:
#        CÓDIGO_ÓRGANO_SUPERIOR                         NOMBRE_ÓRGANO_SUPERIOR  \
# 109737                  30000      Ministério da Justiça e Segurança Pública
# 27928                   25000                         Ministério da Economia
# 84615                   26000                         Ministério da Educação
# 2362                    22000  Ministério da Agricultura, Pecuária e Abastec
# 77998                   26000                         Ministério da Educação
#
#        CÓDIGO_ÓRGANO                                      NOMBRE_ÓRGANO  \
# 109737         30907                       Fundo Penitenciário Nacional
# ...

# %%
se.analisis_descriptivos_numéricas(df_datos_2020)
# Out:
# Las columnas no categóricas son Index(['VALOR_PREVISTO_ACTUALIZADO', 'VALOR_REGISTRADO', 'VALOR_REALIZADO',
#        'PORCENTAJE_REALIZADO', 'FECHA_REGISTRO', 'AÑO_EJERCICIO'],
#       dtype='object')
# Algunos ejemplos de filas son:
#         VALOR_PREVISTO_ACTUALIZADO  VALOR_REGISTRADO  VALOR_REALIZADO  \
# 136812                        0.00              0.00         99507.70
# 84672                         0.00              0.00         13917.95
# 24233                         0.00              0.00           307.40
# 107566                        0.00              0.00        349969.89
# 31358                         0.00              0.00            45.72
#
#         PORCENTAJE_REALIZADO FECHA_REGISTRO  AÑO_EJERCICIO
# 136812                  0.00     2020-11-30           2020
# 84672                   0.00     2020-03-09           2020
# 24233                   0.00     2020-01-15           2020
# 107566                  0.00     2020-01-13           2020
# ...

# %%
df_datos_2020[df_datos_2020.FECHA_REGISTRO.isnull()][df_datos_2020.VALOR_REALIZADO==0][df_datos_2020.VALOR_PREVISTO_ACTUALIZADO==0]
# Out:
#        CÓDIGO_ÓRGANO_SUPERIOR         NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 27004                   25000         Ministério da Economia         25000
# 27867                   25000         Ministério da Economia         25000
# 27871                   25000         Ministério da Economia         25000
# 27910                   25000         Ministério da Economia         25000
# 29560                   25000         Ministério da Economia         30203
# ...                       ...                            ...           ...
# 127118                  32000  Ministério de Minas e Energia         32210
# 127334                  32000  Ministério de Minas e Energia         32210
# 127369                  32000  Ministério de Minas e Energia         32210
# 127566                  32000  Ministério de Minas e Energia         32210
# 140539                  54000          Ministério do Turismo         20203
#
#                                             NOMBRE_ÓRGANO  \
# ...

# %% [markdown]
# # Análisis datos año 2021

# %%
se.traducción_columnas(df_datos_2021)

# %%
df_datos_2021.sample(5)
# Out:
#        CÓDIGO_ÓRGANO_SUPERIOR                         NOMBRE_ÓRGANO_SUPERIOR  \
# 2256                    22000  Ministério da Agricultura, Pecuária e Abastec
# 34020                   25000                         Ministério da Economia
# 29798                   25000                         Ministério da Economia
# 68759                   26000                         Ministério da Educação
# 15616                   52000                           Ministério da Defesa
#
#        CÓDIGO_ÓRGANO                                      NOMBRE_ÓRGANO  \
# 2256           22000  Ministério da Agricultura, Pecuária e Abasteci...
# 34020          25000  Ministério da Economia - Unidades com vínculo ...
# 29798          37904        Fundo do Regime Geral da Previdência Social
# 68759          26273                 Universidade Federal do Rio Grande
# 15616          52132                   Comando da Marinha - Fundo Naval
#
# ...

# %%
se.reporte(df_datos_2021)
# Out:
# La tabla tiene 134593 filas y 16 columnas
# La tabla tiene 0 filas duplicadas
#                            tipo_variables  contador_total  numero_nulos  \
# CÓDIGO_ÓRGANO_SUPERIOR              int64          134593             0
# NOMBRE_ÓRGANO_SUPERIOR             object          134593             0
# CÓDIGO_ÓRGANO                       int64          134593             0
# NOMBRE_ÓRGANO                      object          134593             0
# CÓDIGO_UNIDAD_GESTORA               int64          134593             0
# NOMBRE_UNIDAD_GESTORA              object          134593             0
# CATEGORÍA_ECONÓMICA                object          134593             0
# ORIGEN_INGRESO                     object          134593             0
# TIPO_INGRESO                       object          134593             0
# DETALLE                            object          134593             0
# VALOR_PREVISTO_ACTUALIZADO         object          134593             0
# ...

# %%
se.conversion_columnas(df_datos_2021)
# Out:
# La tabla tiene 134593 filas y 16 columnas
# La tabla tiene 0 filas duplicadas
#                             tipo_variables  contador_total  numero_nulos  \
# CÓDIGO_ÓRGANO_SUPERIOR              object          134593             0
# NOMBRE_ÓRGANO_SUPERIOR              object          134593             0
# CÓDIGO_ÓRGANO                       object          134593             0
# NOMBRE_ÓRGANO                       object          134593             0
# CÓDIGO_UNIDAD_GESTORA               object          134593             0
# NOMBRE_UNIDAD_GESTORA               object          134593             0
# CATEGORÍA_ECONÓMICA                 object          134593             0
# ORIGEN_INGRESO                      object          134593             0
# TIPO_INGRESO                        object          134593             0
# DETALLE                             object          134593             0
# VALOR_PREVISTO_ACTUALIZADO         float64          134593             0
# ...

# %%
se.analisis_descriptivos_categóricas(df_datos_2021)
# Out:
# Las columnas categóricas son Index(['CÓDIGO_ÓRGANO_SUPERIOR', 'NOMBRE_ÓRGANO_SUPERIOR', 'CÓDIGO_ÓRGANO',
#        'NOMBRE_ÓRGANO', 'CÓDIGO_UNIDAD_GESTORA', 'NOMBRE_UNIDAD_GESTORA',
#        'CATEGORÍA_ECONÓMICA', 'ORIGEN_INGRESO', 'TIPO_INGRESO', 'DETALLE'],
#       dtype='object')
# Algunos ejemplos de filas son:
#       CÓDIGO_ÓRGANO_SUPERIOR  NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 72182                  26000  Ministério da Educação         26294
# 13044                  52000    Ministério da Defesa         52904
# 69880                  26000  Ministério da Educação         26431
# 80526                  26000  Ministério da Educação         26294
# 89991                  26000  Ministério da Educação         26282
#
#                               NOMBRE_ÓRGANO CÓDIGO_UNIDAD_GESTORA  \
# 72182  Hospital de Clínicas de Porto Alegre                155001
# 13044                     Fundo do Exército                167086
# ...

# %%
se.analisis_descriptivos_numéricas(df_datos_2021)
# Out:
# Las columnas no categóricas son Index(['VALOR_PREVISTO_ACTUALIZADO', 'VALOR_REGISTRADO', 'VALOR_REALIZADO',
#        'PORCENTAJE_REALIZADO', 'FECHA_REGISTRO', 'AÑO_EJERCICIO'],
#       dtype='object')
# Algunos ejemplos de filas son:
#         VALOR_PREVISTO_ACTUALIZADO  VALOR_REGISTRADO  VALOR_REALIZADO  \
# 98928                         0.00              0.00         91999.22
# 86719                         0.00              0.00           112.94
# 115589                        0.00              0.00           780.44
# 62876                         0.00              0.00         24250.88
# 73268                         0.00              0.00         24323.54
#
#         PORCENTAJE_REALIZADO FECHA_REGISTRO  AÑO_EJERCICIO
# 98928                   0.00     2021-05-21           2021
# 86719                   0.00     2021-02-25           2021
# 115589                  0.00     2021-01-08           2021
# 62876                   0.00     2021-03-04           2021
# ...

# %%
df_datos_2021[df_datos_2021.FECHA_REGISTRO.isnull()][df_datos_2021.VALOR_REALIZADO==0][df_datos_2021.VALOR_PREVISTO_ACTUALIZADO==0]
# Out:
#        CÓDIGO_ÓRGANO_SUPERIOR         NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 24632                   25000         Ministério da Economia         25000
# 24758                   25000         Ministério da Economia         25000
# 24985                   25000         Ministério da Economia         25000
# 25075                   25000         Ministério da Economia         25000
# 25246                   25000         Ministério da Economia         25000
# ...                       ...                            ...           ...
# 121005                  32000  Ministério de Minas e Energia         32210
# 121262                  32000  Ministério de Minas e Energia         32210
# 121288                  32000  Ministério de Minas e Energia         32210
# 122285                  32000  Ministério de Minas e Energia         32396
# 133767                  54000          Ministério do Turismo         20203
#
#                                             NOMBRE_ÓRGANO  \
# ...

# %% [markdown]
# # Análisis columnas de forma individual
# ## Año 2013

# %%
for columna in df_datos_2013.columns:
    print(se.analisis_individual_columnas(df_datos_2013, columna))
# Out:
# La categoría CÓDIGO_ÓRGANO_SUPERIOR tiene 25 elementos diferentes:
#
# Los elementos de la categoría son:
# array(['63000', '37000', '22000', '55000', '24000', '52000', '25000',
#        '26000', '39000', '30000', '81000', '58000', '33000', '36000',
#        '41000', '57000', '35000', '32000', '49000', '53000', '51000',
#        '44000', '38000', '54000', '20000'], dtype=object)
# Los 10 CÓDIGO_ÓRGANO_SUPERIOR que MAS aparecen son:
#                         count  Porcentaje_recuento
# CÓDIGO_ÓRGANO_SUPERIOR
# 26000                    1833                40.75
# 25000                     873                19.41
# 53000                     276                 6.14
# 52000                     228                 5.07
# 22000                     167                 3.71
# 54000                     133                 2.96
# 30000                     129                 2.87
# 39000                     129                 2.87
# 24000                     128                 2.85
# ...

# %% [markdown]
# ## Año 2014

# %%
for columna in df_datos_2014.columns:
    print(se.analisis_individual_columnas(df_datos_2014, columna))
# Out:
# La categoría CÓDIGO_ÓRGANO_SUPERIOR tiene 25 elementos diferentes:
#
# Los elementos de la categoría son:
# array(['63000', '37000', '22000', '55000', '24000', '52000', '25000',
#        '26000', '39000', '30000', '81000', '58000', '33000', '36000',
#        '41000', '57000', '35000', '32000', '49000', '53000', '51000',
#        '44000', '38000', '54000', '20000'], dtype=object)
# Los 10 CÓDIGO_ÓRGANO_SUPERIOR que MAS aparecen son:
#                         count  Porcentaje_recuento
# CÓDIGO_ÓRGANO_SUPERIOR
# 26000                    1841                40.43
# 25000                     900                19.77
# 53000                     308                 6.76
# 52000                     238                 5.23
# 22000                     156                 3.43
# 30000                     133                 2.92
# 54000                     126                 2.77
# 24000                     125                 2.75
# 39000                     124                 2.72
# ...

# %% [markdown]
# ## Año 2015

# %%
for columna in df_datos_2015.columns:
    print(se.analisis_individual_columnas(df_datos_2015, columna))
# Out:
# La categoría CÓDIGO_ÓRGANO_SUPERIOR tiene 25 elementos diferentes:
#
# Los elementos de la categoría son:
# array(['63000', '37000', '22000', '55000', '24000', '52000', '25000',
#        '26000', '39000', '30000', '81000', '58000', '33000', '36000',
#        '41000', '57000', '35000', '32000', '49000', '53000', '51000',
#        '44000', '38000', '54000', '20000'], dtype=object)
# Los 10 CÓDIGO_ÓRGANO_SUPERIOR que MAS aparecen son:
#                         count  Porcentaje_recuento
# CÓDIGO_ÓRGANO_SUPERIOR
# 26000                    1803                39.86
# 25000                     890                19.68
# 53000                     316                 6.99
# 52000                     235                 5.20
# 22000                     154                 3.40
# 54000                     144                 3.18
# 30000                     130                 2.87
# 39000                     124                 2.74
# 24000                     119                 2.63
# ...

# %% [markdown]
# ## Año 2016

# %%
for columna in df_datos_2016.columns:
    print(se.analisis_individual_columnas(df_datos_2016, columna))
# Out:
# La categoría CÓDIGO_ÓRGANO_SUPERIOR tiene 25 elementos diferentes:
#
# Los elementos de la categoría son:
# array(['63000', '37000', '22000', '55000', '24000', '52000', '25000',
#        '26000', '39000', '30000', '81000', '58000', '33000', '36000',
#        '41000', '57000', '35000', '32000', '49000', '53000', '51000',
#        '44000', '38000', '54000', '20000'], dtype=object)
# Los 10 CÓDIGO_ÓRGANO_SUPERIOR que MAS aparecen son:
#                         count  Porcentaje_recuento
# CÓDIGO_ÓRGANO_SUPERIOR
# 26000                   71840                36.93
# 25000                   30019                15.43
# 52000                   17742                 9.12
# 22000                    9321                 4.79
# 30000                    7551                 3.88
# 39000                    7188                 3.70
# 36000                    7082                 3.64
# 53000                    6912                 3.55
# 41000                    6338                 3.26
# ...

# %% [markdown]
# ## Año 2017

# %%
for columna in df_datos_2017.columns:
    print(se.analisis_individual_columnas(df_datos_2017, columna))
# Out:
# La categoría CÓDIGO_ÓRGANO_SUPERIOR tiene 24 elementos diferentes:
#
# Los elementos de la categoría son:
# array(['63000', '37000', '22000', '55000', '24000', '52000', '25000',
#        '26000', '39000', '30000', '81000', '33000', '36000', '41000',
#        '57000', '35000', '32000', '49000', '53000', '51000', '44000',
#        '38000', '54000', '20000'], dtype=object)
# Los 10 CÓDIGO_ÓRGANO_SUPERIOR que MAS aparecen son:
#                         count  Porcentaje_recuento
# CÓDIGO_ÓRGANO_SUPERIOR
# 26000                   70837                37.19
# 25000                   30592                16.06
# 52000                   17644                 9.26
# 22000                    9018                 4.73
# 30000                    7229                 3.80
# 36000                    7183                 3.77
# 39000                    6842                 3.59
# 53000                    6628                 3.48
# 24000                    6076                 3.19
# ...

# %% [markdown]
# ## Año 2018

# %%
for columna in df_datos_2018.columns:
    print(se.analisis_individual_columnas(df_datos_2018, columna))
# Out:
# La categoría CÓDIGO_ÓRGANO_SUPERIOR tiene 22 elementos diferentes:
#
# Los elementos de la categoría son:
# array(['63000', '37000', '22000', '55000', '24000', '52000', '25000',
#        '26000', '39000', '30000', '81000', '33000', '36000', '41000',
#        '57000', '35000', '32000', '53000', '51000', '44000', '54000',
#        '20000'], dtype=object)
# Los 10 CÓDIGO_ÓRGANO_SUPERIOR que MAS aparecen son:
#                         count  Porcentaje_recuento
# CÓDIGO_ÓRGANO_SUPERIOR
# 26000                   65876                37.87
# 25000                   36688                21.09
# 52000                   15387                 8.85
# 22000                    7655                 4.40
# 30000                    6155                 3.54
# 39000                    5964                 3.43
# 32000                    5570                 3.20
# 24000                    5278                 3.03
# 53000                    5049                 2.90
# ...

# %% [markdown]
# ## Año 2019

# %%
for columna in df_datos_2019.columns:
    print(se.analisis_individual_columnas(df_datos_2019, columna))
# Out:
# La categoría CÓDIGO_ÓRGANO_SUPERIOR tiene 20 elementos diferentes:
#
# Los elementos de la categoría son:
# array(['63000', '22000', '55000', '24000', '52000', '25000', '26000',
#        '39000', '30000', '81000', '36000', '41000', '57000', '35000',
#        '32000', '53000', '51000', '44000', '54000', '20000'], dtype=object)
# Los 10 CÓDIGO_ÓRGANO_SUPERIOR que MAS aparecen son:
#                         count  Porcentaje_recuento
# CÓDIGO_ÓRGANO_SUPERIOR
# 26000                   67104                37.95
# 25000                   37788                21.37
# 52000                   15750                 8.91
# 22000                    7361                 4.16
# 30000                    6529                 3.69
# 39000                    6066                 3.43
# 32000                    5516                 3.12
# 24000                    5413                 3.06
# 36000                    5157                 2.92
# 53000                    4962                 2.81
# ...

# %% [markdown]
# ## Año 2020

# %%
for columna in df_datos_2020.columns:
    print(se.analisis_individual_columnas(df_datos_2020, columna))
# Out:
# La categoría CÓDIGO_ÓRGANO_SUPERIOR tiene 20 elementos diferentes:
#
# Los elementos de la categoría son:
# array(['63000', '37000', '22000', '55000', '24000', '52000', '25000',
#        '26000', '39000', '30000', '81000', '36000', '41000', '57000',
#        '35000', '32000', '53000', '44000', '54000', '20000'], dtype=object)
# Los 10 CÓDIGO_ÓRGANO_SUPERIOR que MAS aparecen son:
#                         count  Porcentaje_recuento
# CÓDIGO_ÓRGANO_SUPERIOR
# 26000                   40888                28.72
# 25000                   36037                25.32
# 52000                   14753                10.36
# 22000                    6532                 4.59
# 30000                    6177                 4.34
# 39000                    5741                 4.03
# 24000                    5008                 3.52
# 32000                    4973                 3.49
# 36000                    4542                 3.19
# 53000                    4251                 2.99
# ...

# %%
df_datos_2020.VALOR_PREVISTO_ACTUALIZADO.sum()
# Out:
# np.float64(3577146718910.25)

# %%
df_datos_2020.VALOR_REGISTRADO.sum()
# Out:
# np.float64(706480132443.0701)

# %%
df_datos_2020.VALOR_REALIZADO.sum()
# Out:
# np.float64(3631448629524.17)

# %%
df_datos_2020.VALOR_REALIZADO.sum()/df_datos_2020.VALOR_PREVISTO_ACTUALIZADO.sum()
# Out:
# np.float64(1.0151802301892896)

# %%
df_datos_2020.VALOR_REALIZADO.sum()/df_datos_2020.VALOR_REGISTRADO.sum()
# Out:
# np.float64(5.140199225371425)

# %% [markdown]
# ## Año 2021

# %%
for columna in df_datos_2021.columns:
    print(se.analisis_individual_columnas(df_datos_2021, columna))
# Out:
# La categoría CÓDIGO_ÓRGANO_SUPERIOR tiene 20 elementos diferentes:
#
# Los elementos de la categoría son:
# array(['63000', '37000', '22000', '55000', '24000', '52000', '25000',
#        '26000', '39000', '30000', '81000', '36000', '41000', '57000',
#        '35000', '32000', '53000', '44000', '54000', '20000'], dtype=object)
# Los 10 CÓDIGO_ÓRGANO_SUPERIOR que MAS aparecen son:
#                         count  Porcentaje_recuento
# CÓDIGO_ÓRGANO_SUPERIOR
# 26000                   39869                29.62
# 25000                   33787                25.10
# 52000                   13513                10.04
# 30000                    5947                 4.42
# 22000                    5819                 4.32
# 39000                    5298                 3.94
# 24000                    4766                 3.54
# 32000                    4557                 3.39
# 41000                    4127                 3.07
# 36000                    4110                 3.05
# ...

# %%
df_datos_2021.VALOR_PREVISTO_ACTUALIZADO.sum()
# Out:
# np.float64(4180716471387.52)

# %%
df_datos_2021.VALOR_REGISTRADO.sum()
# Out:
# np.float64(359788769214.59)

# %%
df_datos_2021.VALOR_REALIZADO.sum()
# Out:
# np.float64(3876372024873.041)

# %%
df_datos_2021.VALOR_REALIZADO.sum()/df_datos_2021.VALOR_PREVISTO_ACTUALIZADO.sum()
# Out:
# np.float64(0.9272028015778186)

# %%
df_datos_2021.VALOR_REALIZADO.sum()/df_datos_2021.VALOR_REGISTRADO.sum()
# Out:
# np.float64(10.774021749859132)

# %% [markdown]
# # Unión de todos los años

# %%
df_total_anos = pd.concat([df_datos_2013, df_datos_2014, df_datos_2015, df_datos_2016, df_datos_2017, df_datos_2018, df_datos_2019, df_datos_2020, df_datos_2021], axis=0, ignore_index=0 ).reset_index()

# %%
df_total_anos.rename(columns = {'index': 'INDICE_DF_AÑO_ORIGINAL'})
# Out:
#          INDICE_DF_AÑO_ORIGINAL CÓDIGO_ÓRGANO_SUPERIOR  \
# 0                             0                  63000
# 1                             1                  63000
# 2                             2                  63000
# 3                             3                  63000
# 4                             4                  63000
# ...                         ...                    ...
# 1026294                  134588                  20000
# 1026295                  134589                  20000
# 1026296                  134590                  20000
# 1026297                  134591                  20000
# 1026298                  134592                  20000
#
#            NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 0        Advocacia-Geral da União         63000
# 1        Advocacia-Geral da União         63000
# 2        Advocacia-Geral da União         63000
# 3        Advocacia-Geral da União         63000
# 4        Advocacia-Geral da União         63000
# ...

# %% [markdown]
# ## Análisis datos agrupados

# %%
se.reporte(df_total_anos)
# Out:
# La tabla tiene 1026299 filas y 17 columnas
# La tabla tiene 0 filas duplicadas
#                             tipo_variables  contador_total  numero_nulos  \
# index                                int64         1026299             0
# CÓDIGO_ÓRGANO_SUPERIOR              object         1026299             0
# NOMBRE_ÓRGANO_SUPERIOR              object         1026299             0
# CÓDIGO_ÓRGANO                       object         1026299             0
# NOMBRE_ÓRGANO                       object         1026299             0
# CÓDIGO_UNIDAD_GESTORA               object         1026299             0
# NOMBRE_UNIDAD_GESTORA               object         1026299             0
# CATEGORÍA_ECONÓMICA                 object         1026299             0
# ORIGEN_INGRESO                      object         1026299             0
# TIPO_INGRESO                        object         1026299             0
# DETALLE                             object         1026299             0
# ...

# %%
se.analisis_descriptivos_categóricas(df_total_anos)
# Out:
# Las columnas categóricas son Index(['CÓDIGO_ÓRGANO_SUPERIOR', 'NOMBRE_ÓRGANO_SUPERIOR', 'CÓDIGO_ÓRGANO',
#        'NOMBRE_ÓRGANO', 'CÓDIGO_UNIDAD_GESTORA', 'NOMBRE_UNIDAD_GESTORA',
#        'CATEGORÍA_ECONÓMICA', 'ORIGEN_INGRESO', 'TIPO_INGRESO', 'DETALLE'],
#       dtype='object')
# Algunos ejemplos de filas son:
#        CÓDIGO_ÓRGANO_SUPERIOR                         NOMBRE_ÓRGANO_SUPERIOR  \
# 934550                  25000                         Ministério da Economia
# 539407                  30000      Ministério da Justiça e Segurança Pública
# 167256                  81000  Ministério da Mulher, Família e Direitos Huma
# 446289                  25000                         Ministério da Economia
# 762998                  52000                           Ministério da Defesa
#
#        CÓDIGO_ÓRGANO                                      NOMBRE_ÓRGANO  \
# 934550         25207          Serviço Federal de Processamento de Dados
# ...

# %% [markdown]
# ## Análisis columnas numéricas

# %%
se.analisis_descriptivos_numéricas(df_total_anos)
# Out:
# Las columnas no categóricas son Index(['index', 'VALOR_PREVISTO_ACTUALIZADO', 'VALOR_REGISTRADO',
#        'VALOR_REALIZADO', 'PORCENTAJE_REALIZADO', 'FECHA_REGISTRO',
#        'AÑO_EJERCICIO'],
#       dtype='object')
# Algunos ejemplos de filas son:
#          index  VALOR_PREVISTO_ACTUALIZADO  VALOR_REGISTRADO  VALOR_REALIZADO  \
# 676634  104104                        0.00              0.00            55.00
# 821545   72187                        0.00              0.00          2390.00
# 388727  180620                        0.00              0.00          2496.12
# 987971   96265                        0.00              0.00            42.00
# 201432  187858                        0.00              0.00         69251.05
#
#         PORCENTAJE_REALIZADO FECHA_REGISTRO  AÑO_EJERCICIO
# 676634                  0.00     2019-12-04           2019
# 821545                  0.00     2020-01-22           2020
# 388727                  0.00     2017-12-26           2017
# ...

# %%
df_importes_agrupación_organo_superior = df_total_anos.groupby('NOMBRE_ÓRGANO_SUPERIOR')[['VALOR_PREVISTO_ACTUALIZADO',
       'VALOR_REGISTRADO', 'VALOR_REALIZADO', 'PORCENTAJE_REALIZADO']].sum()

df_importes_agrupación_organo_superior
# Out:
#                                                VALOR_PREVISTO_ACTUALIZADO  \
# NOMBRE_ÓRGANO_SUPERIOR
# Advocacia-Geral da União                                    3726053651.00
# Controladoria-Geral da União                                 740692856.00
# Ministério da Agricultura, Pecuária e Abastec              87492532893.00
# Ministério da Cidadania                                    43958882249.00
# Ministério da Ciência, Tecnologia, Inovações               62254372476.31
# Ministério da Defesa                                      198522792044.00
# Ministério da Economia                                  26486420136019.00
# Ministério da Educação                                    609585887826.00
# Ministério da Infraestrutura                              119972882836.00
# Ministério da Justiça e Segurança Pública                  36304805355.02
# Ministério da Mulher, Família e Direitos Huma                843366940.00
# ...

# %%
df_importes_agrupación_organo_superior["VALOR_REALIZADO/VALOR_PREVISTO_ACTUALIZADO"] = (df_importes_agrupación_organo_superior.VALOR_REALIZADO/df_importes_agrupación_organo_superior.VALOR_PREVISTO_ACTUALIZADO)*100

# %%
df_importes_agrupación_organo_superior["VALOR_REGISTRADO/VALOR_PREVISTO_ACTUALIZADO"] =(df_importes_agrupación_organo_superior.VALOR_REGISTRADO/df_importes_agrupación_organo_superior.VALOR_PREVISTO_ACTUALIZADO)*100

# %%
df_importes_agrupación_organo_superior
# Out:
#                                                VALOR_PREVISTO_ACTUALIZADO  \
# NOMBRE_ÓRGANO_SUPERIOR
# Advocacia-Geral da União                                    3726053651.00
# Controladoria-Geral da União                                 740692856.00
# Ministério da Agricultura, Pecuária e Abastec              87492532893.00
# Ministério da Cidadania                                    43958882249.00
# Ministério da Ciência, Tecnologia, Inovações               62254372476.31
# Ministério da Defesa                                      198522792044.00
# Ministério da Economia                                  26486420136019.00
# Ministério da Educação                                    609585887826.00
# Ministério da Infraestrutura                              119972882836.00
# Ministério da Justiça e Segurança Pública                  36304805355.02
# Ministério da Mulher, Família e Direitos Huma                843366940.00
# ...

# %%
df_total_anos.groupby('NOMBRE_ÓRGANO_SUPERIOR')[['VALOR_PREVISTO_ACTUALIZADO',
       'VALOR_REGISTRADO', 'VALOR_REALIZADO', 'PORCENTAJE_REALIZADO']].mean()
# Out:
#                                                VALOR_PREVISTO_ACTUALIZADO  \
# NOMBRE_ÓRGANO_SUPERIOR
# Advocacia-Geral da União                                        955643.41
# Controladoria-Geral da União                                   2939257.37
# Ministério da Agricultura, Pecuária e Abastec                  1894474.87
# Ministério da Cidadania                                        7453184.51
# Ministério da Ciência, Tecnologia, Inovações                   1895341.06
# Ministério da Defesa                                           2078990.39
# Ministério da Economia                                       127599892.74
# Ministério da Educação                                         1684446.11
# Ministério da Infraestrutura                                   3201325.72
# Ministério da Justiça e Segurança Pública                       908074.17
# Ministério da Mulher, Família e Direitos Huma                   728925.62
# ...

# %%
df_total_anos[df_total_anos.FECHA_REGISTRO.isnull()]
# Out:
#           index CÓDIGO_ÓRGANO_SUPERIOR  \
# 31715     18141                  24000
# 50971     37397                  25000
# 51032     37458                  25000
# 51747     38173                  25000
# 51977     38403                  25000
# ...         ...                    ...
# 1012711  121005                  32000
# 1012968  121262                  32000
# 1012994  121288                  32000
# 1013991  122285                  32000
# 1025473  133767                  54000
#
#                                 NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 31715    Ministério da Ciência, Tecnologia, Inovações          20501
# 50971                           Ministério da Economia         25000
# 51032                           Ministério da Economia         25000
# 51747                           Ministério da Economia         25000
# 51977                           Ministério da Economia         25000
# ...                                                ...           ...
# ...

# %%
df_total_anos.columns
# Out:
# Index(['index', 'CÓDIGO_ÓRGANO_SUPERIOR', 'NOMBRE_ÓRGANO_SUPERIOR',
#        'CÓDIGO_ÓRGANO', 'NOMBRE_ÓRGANO', 'CÓDIGO_UNIDAD_GESTORA',
#        'NOMBRE_UNIDAD_GESTORA', 'CATEGORÍA_ECONÓMICA', 'ORIGEN_INGRESO',
#        'TIPO_INGRESO', 'DETALLE', 'VALOR_PREVISTO_ACTUALIZADO',
#        'VALOR_REGISTRADO', 'VALOR_REALIZADO', 'PORCENTAJE_REALIZADO',
#        'FECHA_REGISTRO', 'AÑO_EJERCICIO'],
#       dtype='object')

# %%
df_total_anos[df_total_anos.VALOR_PREVISTO_ACTUALIZADO!=0].FECHA_REGISTRO.value_counts()
# Out:
# FECHA_REGISTRO
# 2013-12-31    2873
# 2014-12-31    2847
# 2015-12-31    2738
# 2020-01-20    1993
# 2018-01-12    1899
# 2016-01-21    1888
# 2017-01-19    1875
# 2019-01-31    1850
# 2021-04-23    1844
# 2017-01-23       6
# 2016-06-08       3
# 2017-07-25       3
# 2017-03-31       3
# 2017-03-29       3
# 2016-01-13       3
# 2019-10-11       3
# 2018-08-28       3
# 2020-07-08       3
# 2021-04-29       3
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.VALOR_REGISTRADO!=0].FECHA_REGISTRO.value_counts()
# Out:
# FECHA_REGISTRO
# 2020-02-28    108
# 2020-08-31    106
# 2021-08-24    104
# 2021-11-26    104
# 2021-06-23    103
#              ...
# 2021-01-29      1
# 2021-10-30      1
# 2021-11-05      1
# 2021-11-04      1
# 2021-05-28      1
# Name: count, Length: 253, dtype: int64

# %% [markdown]
# ## Análisis columnas individualmente

# %%
for columna in df_total_anos.columns:
    print(se.analisis_individual_columnas(df_total_anos, columna))
# Out:
# La categoría index tiene 194533 elementos diferentes:
#
# Los elementos de la categoría son:
# array([     0,      1,      2, ..., 194530, 194531, 194532])
# Los 10 index que MAS aparecen son:
#        count  Porcentaje_recuento
# index
# 16         9                 0.00
# 13         9                 0.00
# 17         9                 0.00
# 18         9                 0.00
# 19         9                 0.00
# 20         9                 0.00
# 21         9                 0.00
# 22         9                 0.00
# 23         9                 0.00
# 24         9                 0.00
# Los 10 index que MENOS aparecen son:
#         count  Porcentaje_recuento
# index
# 194527      1                 0.00
# 194526      1                 0.00
# 194525      1                 0.00
# 194524      1                 0.00
# 194523      1                 0.00
# 194522      1                 0.00
# 194521      1                 0.00
# 194520      1                 0.00
# ...

# %% [markdown]
# ## Análisis posibles duplicados

# %% [markdown]
# ### a.  Nombre órgano superior

# %%
df_total_anos['CODIGO_NOMBRE_ORGANO_SUPERIOR'] = df_total_anos.CÓDIGO_ÓRGANO_SUPERIOR+ '-' + df_total_anos.NOMBRE_ÓRGANO_SUPERIOR

# %%
df_total_anos
# Out:
#           index CÓDIGO_ÓRGANO_SUPERIOR    NOMBRE_ÓRGANO_SUPERIOR  \
# 0             0                  63000  Advocacia-Geral da União
# 1             1                  63000  Advocacia-Geral da União
# 2             2                  63000  Advocacia-Geral da União
# 3             3                  63000  Advocacia-Geral da União
# 4             4                  63000  Advocacia-Geral da União
# ...         ...                    ...                       ...
# 1026294  134588                  20000  Presidência da República
# 1026295  134589                  20000  Presidência da República
# 1026296  134590                  20000  Presidência da República
# 1026297  134591                  20000  Presidência da República
# 1026298  134592                  20000  Presidência da República
#
#         CÓDIGO_ÓRGANO                                      NOMBRE_ÓRGANO  \
# 0               63000  Advocacia-Geral da União - Unidades com víncul...
# ...

# %%
df_total_anos['CODIGO_NOMBRE_ORGANO'] = df_total_anos.CÓDIGO_ÓRGANO+ '-' + df_total_anos.NOMBRE_ÓRGANO

# %%
df_total_anos
# Out:
#           index CÓDIGO_ÓRGANO_SUPERIOR    NOMBRE_ÓRGANO_SUPERIOR  \
# 0             0                  63000  Advocacia-Geral da União
# 1             1                  63000  Advocacia-Geral da União
# 2             2                  63000  Advocacia-Geral da União
# 3             3                  63000  Advocacia-Geral da União
# 4             4                  63000  Advocacia-Geral da União
# ...         ...                    ...                       ...
# 1026294  134588                  20000  Presidência da República
# 1026295  134589                  20000  Presidência da República
# 1026296  134590                  20000  Presidência da República
# 1026297  134591                  20000  Presidência da República
# 1026298  134592                  20000  Presidência da República
#
#         CÓDIGO_ÓRGANO                                      NOMBRE_ÓRGANO  \
# 0               63000  Advocacia-Geral da União - Unidades com víncul...
# ...

# %%
df_contador_codigos_nombre_organos_total = df_total_anos['CODIGO_NOMBRE_ORGANO'].value_counts().reset_index()
df_contador_codigos_nombre_organos_total
# Out:
#                                   CODIGO_NOMBRE_ORGANO   count
# 0    25000-Ministério da Economia - Unidades com ví...  119811
# 1                              52904-Fundo do Exército   25559
# 2               52132-Comando da Marinha - Fundo Naval   23734
# 3                      34902-Fundo Nacional de Cultura   15955
# 4    20701-Instituto Brasileiro do Meio Ambiente e ...   13745
# ..                                                 ...     ...
# 286                36208-Hospital Cristo Redentor S.A.       2
# 287       53205-Agência de Desenvolvimento da Amazônia       2
# 288  29201-Departamento Nacional de Estradas de Rod...       1
# 289    20605-Companhia de Desenvolvimento de Barcarena       1
# 290                         36209-Hospital Fêmina S.A.       1
#
# [291 rows x 2 columns]

# %%
df_contador_codigos_nombre_organos_total["nombre"] =df_contador_codigos_nombre_organos_total.CODIGO_NOMBRE_ORGANO.str.split("-",expand=True)[1]
df_contador_codigos_nombre_organos_total
# Out:
#                                   CODIGO_NOMBRE_ORGANO   count  \
# 0    25000-Ministério da Economia - Unidades com ví...  119811
# 1                              52904-Fundo do Exército   25559
# 2               52132-Comando da Marinha - Fundo Naval   23734
# 3                      34902-Fundo Nacional de Cultura   15955
# 4    20701-Instituto Brasileiro do Meio Ambiente e ...   13745
# ..                                                 ...     ...
# 286                36208-Hospital Cristo Redentor S.A.       2
# 287       53205-Agência de Desenvolvimento da Amazônia       2
# 288  29201-Departamento Nacional de Estradas de Rod...       1
# 289    20605-Companhia de Desenvolvimento de Barcarena       1
# 290                         36209-Hospital Fêmina S.A.       1
#
#                                                 nombre
# 0                              Ministério da Economia
# 1                                    Fundo do Exército
# ...

# %%
df_contador_nombres = df_contador_codigos_nombre_organos_total['nombre'].value_counts().reset_index()

# %%
df_contador_nombres[df_contador_nombres['count'] >1]
# Out:
#                                           nombre  count
# 0                      Fundo Nacional Antidrogas      2
# 1    Agência Nacional de Transportes Aquaviários      2
# 2  Fundo Nacional para a Criança e o Adolescente      2
# 3                        Fundo Nacional do Idoso      2
# 4                                  Controladoria      2

# %%
df_total_anos[df_total_anos.NOMBRE_ÓRGANO == 'Fundo Nacional Antidrogas'].CODIGO_NOMBRE_ORGANO.value_counts()
# Out:
# CODIGO_NOMBRE_ORGANO
# 30912-Fundo Nacional Antidrogas    7596
# 20117-Fundo Nacional Antidrogas      20
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.NOMBRE_ÓRGANO == 'Agência Nacional de Transportes Aquaviários'].CODIGO_NOMBRE_ORGANO.value_counts()
# Out:
# CODIGO_NOMBRE_ORGANO
# 68201-Agência Nacional de Transportes Aquaviários    2178
# 39251-Agência Nacional de Transportes Aquaviários       5
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.NOMBRE_ÓRGANO == 'Fundo Nacional para a Criança e o Adolescente'].CODIGO_NOMBRE_ORGANO.value_counts()
# Out:
# CODIGO_NOMBRE_ORGANO
# 30913-Fundo Nacional para a Criança e o Adolescente    746
# 64901-Fundo Nacional para a Criança e o Adolescente    184
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.NOMBRE_ÓRGANO == 'Fundo Nacional do Idoso'].CODIGO_NOMBRE_ORGANO.value_counts()
# Out:
# CODIGO_NOMBRE_ORGANO
# 30914-Fundo Nacional do Idoso    230
# 64902-Fundo Nacional do Idoso    101
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.NOMBRE_ÓRGANO.str.contains('Controladoria')].CODIGO_NOMBRE_ORGANO.value_counts()
# Out:
# CODIGO_NOMBRE_ORGANO
# 66000-Controladoria-Geral da União                                  172
# 37000-Controladoria-Geral da União - Unidades com vínculo direto     80
# Name: count, dtype: int64

# %% [markdown]
# ### b. Nombre unidad gestora

# %%
df_total_anos['CODIGO_NOMBRE_UNIDAD_GESTORA'] = df_total_anos.CÓDIGO_UNIDAD_GESTORA+ '|' + df_total_anos.NOMBRE_UNIDAD_GESTORA

# %%
df_contador_codigos_nombre_unidad_gestora_total = df_total_anos['CODIGO_NOMBRE_UNIDAD_GESTORA'].value_counts().reset_index()
df_contador_codigos_nombre_unidad_gestora_total
# Out:
#                           CODIGO_NOMBRE_UNIDAD_GESTORA   count
# 0       170013|SETORIAL ORCAMENTARIA E FINANCEIRA / ME  108481
# 1                             167086|FUNDO DO EXERCITO   25469
# 2    673001|DIRETORIA DE FINANCAS-SISTEMA PARA O PA...   19196
# 3    193034|IBAMA - INST.BRASILEIRO MEIO AMBIENTE/M...   13698
# 4                              135037|EMBRAPA-SETORIAL   13641
# ..                                                 ...     ...
# 359      533001|AGENCIA DE DESENVOLVIMENTO DA AMAZONIA       2
# 360                         366002|HOSPITAL FEMINA S/A       1
# 361  200337|COORDENACAO DE ORCAMENTO E FINANCAS - C...       1
# 362   195008|COMPANHIA DE DESENVOLVIMENTO DE BARCARENA       1
# 363  273087|DEPARTAMENTO NAC. ESTRADAS E RODAGEM-EX...       1
#
# [364 rows x 2 columns]

# %%
df_contador_codigos_nombre_unidad_gestora_total["nombre"] =df_contador_codigos_nombre_unidad_gestora_total.CODIGO_NOMBRE_UNIDAD_GESTORA.str.split("|",expand=True)[1]
df_contador_codigos_nombre_unidad_gestora_total
# Out:
#                           CODIGO_NOMBRE_UNIDAD_GESTORA   count  \
# 0       170013|SETORIAL ORCAMENTARIA E FINANCEIRA / ME  108481
# 1                             167086|FUNDO DO EXERCITO   25469
# 2    673001|DIRETORIA DE FINANCAS-SISTEMA PARA O PA...   19196
# 3    193034|IBAMA - INST.BRASILEIRO MEIO AMBIENTE/M...   13698
# 4                              135037|EMBRAPA-SETORIAL   13641
# ..                                                 ...     ...
# 359      533001|AGENCIA DE DESENVOLVIMENTO DA AMAZONIA       2
# 360                         366002|HOSPITAL FEMINA S/A       1
# 361  200337|COORDENACAO DE ORCAMENTO E FINANCAS - C...       1
# 362   195008|COMPANHIA DE DESENVOLVIMENTO DE BARCARENA       1
# 363  273087|DEPARTAMENTO NAC. ESTRADAS E RODAGEM-EX...       1
#
#                                             nombre
# 0          SETORIAL ORCAMENTARIA E FINANCEIRA / ME
# 1                                FUNDO DO EXERCITO
# 2     DIRETORIA DE FINANCAS-SISTEMA PARA O PAIS/MM
# ...

# %%
df_contador_nombres_unidad_gestora = df_contador_codigos_nombre_unidad_gestora_total['nombre'].value_counts().reset_index()

# %%
df_contador_nombres_unidad_gestora[df_contador_nombres_unidad_gestora['count'] >1]
# Out:
#                                           nombre  count
# 0       COORDENACAO-GERAL DE RECURSOS LOGISTICOS      2
# 1                      FUNDO NACIONAL ANTIDROGAS      2
# 2      COORDENACAO-GERAL DE ORCAMENTO E FINANCAS      2
# 3    AGENCIA NACIONAL DE TRANSPORTES AQUAVIARIOS      2
# 4   DIRETORIA DE FINANCAS-SISTEMA PARA O PAIS/MM      2
# 5  FUNDO NACIONAL PARA A CRIANCA E O ADOLESCENTE      2
# 6    SETORIAL PROG.ORCAMENTARIA E FINANCEIRA-SFB      2
# 7                        FUNDO NACIONAL DO IDOSO      2

# %%
df_total_anos[df_total_anos.NOMBRE_UNIDAD_GESTORA == 'COORDENACAO-GERAL DE RECURSOS LOGISTICOS'].CODIGO_NOMBRE_UNIDAD_GESTORA.value_counts()
# Out:
# CODIGO_NOMBRE_UNIDAD_GESTORA
# 410003|COORDENACAO-GERAL DE RECURSOS LOGISTICOS    4
# 240101|COORDENACAO-GERAL DE RECURSOS LOGISTICOS    3
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.NOMBRE_UNIDAD_GESTORA == 'FUNDO NACIONAL ANTIDROGAS'].CODIGO_NOMBRE_UNIDAD_GESTORA.value_counts()
# Out:
# CODIGO_NOMBRE_UNIDAD_GESTORA
# 200246|FUNDO NACIONAL ANTIDROGAS    7596
# 110246|FUNDO NACIONAL ANTIDROGAS      20
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.NOMBRE_UNIDAD_GESTORA == 'COORDENACAO-GERAL DE ORCAMENTO E FINANCAS'].CODIGO_NOMBRE_UNIDAD_GESTORA.value_counts()
# Out:
# CODIGO_NOMBRE_UNIDAD_GESTORA
# 240102|COORDENACAO-GERAL DE ORCAMENTO E FINANCAS    5532
# 410002|COORDENACAO-GERAL DE ORCAMENTO E FINANCAS     308
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.NOMBRE_UNIDAD_GESTORA == 'AGENCIA NACIONAL DE TRANSPORTES AQUAVIARIOS'].CODIGO_NOMBRE_UNIDAD_GESTORA.value_counts()
# Out:
# CODIGO_NOMBRE_UNIDAD_GESTORA
# 682010|AGENCIA NACIONAL DE TRANSPORTES AQUAVIARIOS    2178
# 393002|AGENCIA NACIONAL DE TRANSPORTES AQUAVIARIOS       5
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.NOMBRE_UNIDAD_GESTORA == 'DIRETORIA DE FINANCAS-SISTEMA PARA O PAIS/MM'].CODIGO_NOMBRE_UNIDAD_GESTORA.value_counts()
# Out:
# CODIGO_NOMBRE_UNIDAD_GESTORA
# 673001|DIRETORIA DE FINANCAS-SISTEMA PARA O PAIS/MM    19196
# 873001|DIRETORIA DE FINANCAS-SISTEMA PARA O PAIS/MM     4336
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.NOMBRE_UNIDAD_GESTORA == 'FUNDO NACIONAL PARA A CRIANCA E O ADOLESCENTE'].CODIGO_NOMBRE_UNIDAD_GESTORA.value_counts()
# Out:
# CODIGO_NOMBRE_UNIDAD_GESTORA
# 307001|FUNDO NACIONAL PARA A CRIANCA E O ADOLESCENTE    746
# 110244|FUNDO NACIONAL PARA A CRIANCA E O ADOLESCENTE    168
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.NOMBRE_UNIDAD_GESTORA == 'SETORIAL PROG.ORCAMENTARIA E FINANCEIRA-SFB'].CODIGO_NOMBRE_UNIDAD_GESTORA.value_counts()
# Out:
# CODIGO_NOMBRE_UNIDAD_GESTORA
# 440088|SETORIAL PROG.ORCAMENTARIA E FINANCEIRA-SFB    609
# 130214|SETORIAL PROG.ORCAMENTARIA E FINANCEIRA-SFB      7
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.NOMBRE_UNIDAD_GESTORA == 'FUNDO NACIONAL DO IDOSO'].CODIGO_NOMBRE_UNIDAD_GESTORA.value_counts()
# Out:
# CODIGO_NOMBRE_UNIDAD_GESTORA
# 307002|FUNDO NACIONAL DO IDOSO    230
# 207001|FUNDO NACIONAL DO IDOSO     89
# Name: count, dtype: int64

# %% [markdown]
# ### c. Categoría económica

# %% [markdown]
# Según los datos iniciales, la categoría económica solo debía tener dos opciones (Receitas Correntes y Receitas de capital), no obstante, esta columna tiene más valores:

# %%
df_total_anos.CATEGORÍA_ECONÓMICA.value_counts()
# Out:
# CATEGORÍA_ECONÓMICA
# Receitas Correntes                           979596
# Receitas de Capital                           30116
# Receitas Correntes - intra-orçamentárias      16235
# Sem informação                                  257
# Receitas de Capital - intra-orçamentárias        95
# Name: count, dtype: int64

# %% [markdown]
# intra-orçamentárias significa, intraprespuestarias, es decir dentro de presupuesto, por lo tanto, entendiendo que todos los ingresos están dentro de presupuestos, elimino la parte intra-orçamentárias de la categoría y creo una nueva columna para agruparlo

# %%
df_total_anos["CATEGORIA_ECONÓMICA_AGRUPADA"] = df_total_anos.CATEGORÍA_ECONÓMICA.str.split("-",expand=True)[0].str.rstrip()

# %%
df_total_anos.CATEGORIA_ECONÓMICA_AGRUPADA.value_counts()
# Out:
# CATEGORIA_ECONÓMICA_AGRUPADA
# Receitas Correntes     995831
# Receitas de Capital     30211
# Sem informação            257
# Name: count, dtype: int64

# %% [markdown]
# ### Análisis origen ingreso si está correctamente categorizado

# %%
print(f'Las categorias de recetas corrientes y recetas de capital son:')
df_categorias_recetas_corrientes_y_capital= df_diccionario_datos[df_diccionario_datos.DESCRIÇÃO.notnull()][df_diccionario_datos['Unnamed: 3'].notnull()]
df_categorias_recetas_corrientes_y_capital[['DESCRIÇÃO','Unnamed: 3']]
# Out:
# Las categorias de recetas corrientes y recetas de capital son:
#                       DESCRIÇÃO                                   Unnamed: 3
# 21   Para Receitas Correntes:                   Para Receitas Correntes:
# 22                           1.  Impostos, Taxas e Contribuições de Melhoria
# 23                           2.                                Contribuições
# 24                           3.                          Receita Patrimonial
# 25                           4.                         Receita Agropecuária
# 26                           5.                           Receita Industrial
# 27                           6.                          Receita de Serviços
# 28                           7.                     Transferências Correntes
# 30  Para Receitas de Capital:                  Para Receitas de Capital:
# 31                           1.                         Operações de Crédito
# ...

# %% [markdown]
# Por tanto, Receitas correntes solo debe tener:
# 1.	Impostos, Taxas e Contribuições de Melhoria
# 2.	Contribuições
# 3.	Receita Patrimonial
# 4.	Receita Agropecuária
# 5.	Receita Industrial
# 6.	Receita de Serviços
# 7.	Transferências Correntes

# %%
df_total_anos[df_total_anos.CATEGORÍA_ECONÓMICA == 'Receitas Correntes'].ORIGEN_INGRESO.value_counts()
# Out:
# ORIGEN_INGRESO
# Outras Receitas Correntes                      321508
# Receita de Serviços                            316635
# Receita Patrimonial                            161974
# Impostos, Taxas e Contribuições de Melhoria     75208
# Contribuições                                   64911
# Receita Industrial                              15904
# Receita Agropecuária                            13642
# Transferências Correntes                         6385
# Receitas Correntes - a classificar               3429
# Name: count, dtype: int64

# %% [markdown]
# Todas tienen una categoría correcta.
#
# Analizo las Receitas Correntes - a clasificar

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Receitas Correntes - a classificar'].sample(5)
# Out:
#          index CÓDIGO_ÓRGANO_SUPERIOR        NOMBRE_ÓRGANO_SUPERIOR  \
# 113478   99904                  26000        Ministério da Educação
# 804332   54974                  25000        Ministério da Economia
# 607532   35002                  25000        Ministério da Economia
# 442775   44189                  25000        Ministério da Economia
# 153061  139487                  39000  Ministério da Infraestrutura
#
#        CÓDIGO_ÓRGANO                                      NOMBRE_ÓRGANO  \
# 113478         26271                  Fundação Universidade de Brasília
# 804332         25207          Serviço Federal de Processamento de Dados
# 607532         25207          Serviço Federal de Processamento de Dados
# 442775         22500  Companhia de Entrepostos e Armazéns Gerais de ...
# 153061         39811                  Companhia Docas do Rio de Janeiro
#
#        CÓDIGO_UNIDAD_GESTORA                         NOMBRE_UNIDAD_GESTORA  \
# ...

# %%
se.reporte(df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Receitas Correntes - a classificar'])
# Out:
# La tabla tiene 3429 filas y 21 columnas
# La tabla tiene 0 filas duplicadas
#                                tipo_variables  contador_total  numero_nulos  \
# index                                   int64            3429             0
# CÓDIGO_ÓRGANO_SUPERIOR                 object            3429             0
# NOMBRE_ÓRGANO_SUPERIOR                 object            3429             0
# CÓDIGO_ÓRGANO                          object            3429             0
# NOMBRE_ÓRGANO                          object            3429             0
# CÓDIGO_UNIDAD_GESTORA                  object            3429             0
# NOMBRE_UNIDAD_GESTORA                  object            3429             0
# CATEGORÍA_ECONÓMICA                    object            3429             0
# ORIGEN_INGRESO                         object            3429             0
# TIPO_INGRESO                           object            3429             0
# ...

# %% [markdown]
# En detalle hay 2 tipos de detalles. Analizo los 2 que aparecen por si puede ayudarme a saber qué tipo de categoría económica es:

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Receitas Correntes - a classificar'].DETALLE.value_counts()
# Out:
# DETALLE
# Receitas Correntes - a classificar    3413
# RECEITAS CORRENTES A CLASSIFICAR        16
# Name: count, dtype: int64

# %% [markdown]
# Parece que en la columna DETALLE está duplicada la categoría, sustituyo RECEITAS CORRENTES A CLASSIFICAR por Receitas Correntes - a classificar

# %%
df_total_anos['DETALLE'] = df_total_anos['DETALLE'].str.replace('RECEITAS CORRENTES A CLASSIFICAR', 'Receitas Correntes - a classificar')

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Receitas Correntes - a classificar'].DETALLE.value_counts()
# Out:
# DETALLE
# Receitas Correntes - a classificar    3429
# Name: count, dtype: int64

# %% [markdown]
# Analizo Transferências Correntes

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Receitas Correntes - a classificar'].sample(5)
